# %% [markdown]
# # TransTVDiag Evaluation

# %%
# !pip install torch==2.1.1
# !pip install dgl -f https://data.dgl.ai/wheels/torch-2.1/cu121/repo.html
# !pip install scikit-learn
# !pip install fasttext==0.9.2
# Out:
# Looking in indexes: https://artifactory.tcsbank.ru/artifactory/api/pypi/python-all/simple
# Requirement already satisfied: torch==2.1.1 in /home/mlcore/conda/lib/python3.10/site-packages (2.1.1)
# Requirement already satisfied: filelock in /home/mlcore/conda/lib/python3.10/site-packages (from torch==2.1.1) (3.25.1)
# Requirement already satisfied: typing-extensions in /home/mlcore/conda/lib/python3.10/site-packages (from torch==2.1.1) (4.15.0)
# Requirement already satisfied: sympy in /home/mlcore/conda/lib/python3.10/site-packages (from torch==2.1.1) (1.14.0)
# Requirement already satisfied: networkx in /home/mlcore/conda/lib/python3.10/site-packages (from torch==2.1.1) (3.4.2)
# Requirement already satisfied: jinja2 in /home/mlcore/.local/lib/python3.10/site-packages (from torch==2.1.1) (3.1.6)
# Requirement already satisfied: fsspec in /home/mlcore/.local/lib/python3.10/site-packages (from torch==2.1.1) (2026.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/mlcore/conda/lib/python3.10/site-packages (from torch==2.1.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/mlcore/conda/lib/python3.10/site-packages (from torch==2.1.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/mlcore/conda/lib/python3.10/site-packages (from torch==2.1.1) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/mlcore/conda/lib/python3.10/site-packages (from torch==2.1.1) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/mlcore/conda/lib/python3.10/site-packages (from torch==2.1.1) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/mlcore/conda/lib/python3.10/site-packages (from torch==2.1.1) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/mlcore/conda/lib/python3.10/site-packages (from torch==2.1.1) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/mlcore/conda/lib/python3.10/site-packages (from torch==2.1.1) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/mlcore/conda/lib/python3.10/site-packages (from torch==2.1.1) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /home/mlcore/conda/lib/python3.10/site-packages (from torch==2.1.1) (2.18.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/mlcore/conda/lib/python3.10/site-packages (from torch==2.1.1) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in /home/mlcore/conda/lib/python3.10/site-packages (from torch==2.1.1) (2.1.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/mlcore/conda/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.1.1) (12.9.86)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/mlcore/.local/lib/python3.10/site-packages (from jinja2->torch==2.1.1) (3.0.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/mlcore/conda/lib/python3.10/site-packages (from sympy->torch==2.1.1) (1.3.0)
#
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python3.10 -m pip install --upgrade pip
# Looking in indexes: https://artifactory.tcsbank.ru/artifactory/api/pypi/python-all/simple
# Looking in links: https://data.dgl.ai/wheels/torch-2.1/cu121/repo.html
# Requirement already satisfied: dgl in /home/mlcore/conda/lib/python3.10/site-packages (2.4.0+cu121)
# Requirement already satisfied: networkx>=2.1 in /home/mlcore/conda/lib/python3.10/site-packages (from dgl) (3.4.2)
# Requirement already satisfied: numpy>=1.14.0 in /home/mlcore/conda/lib/python3.10/site-packages (from dgl) (1.26.4)
# Requirement already satisfied: packaging in /home/mlcore/conda/lib/python3.10/site-packages (from dgl) (26.0)
# Requirement already satisfied: pandas in /home/mlcore/.local/lib/python3.10/site-packages (from dgl) (2.2.0)
# Requirement already satisfied: psutil>=5.8.0 in /home/mlcore/.local/lib/python3.10/site-packages (from dgl) (5.9.8)
# Requirement already satisfied: pydantic>=2.0 in /home/mlcore/.local/lib/python3.10/site-packages (from dgl) (2.12.5)
# Requirement already satisfied: pyyaml in /home/mlcore/conda/lib/python3.10/site-packages (from dgl) (6.0.3)
# Requirement already satisfied: requests>=2.19.0 in /home/mlcore/.local/lib/python3.10/site-packages (from dgl) (2.33.1)
# Requirement already satisfied: scipy>=1.1.0 in /home/mlcore/conda/lib/python3.10/site-packages (from dgl) (1.15.3)
# Requirement already satisfied: tqdm in /home/mlcore/conda/lib/python3.10/site-packages (from dgl) (4.64.1)
# Requirement already satisfied: torch<=2.4.0 in /home/mlcore/conda/lib/python3.10/site-packages (from dgl) (2.1.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/mlcore/.local/lib/python3.10/site-packages (from pydantic>=2.0->dgl) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/mlcore/.local/lib/python3.10/site-packages (from pydantic>=2.0->dgl) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in /home/mlcore/conda/lib/python3.10/site-packages (from pydantic>=2.0->dgl) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/mlcore/.local/lib/python3.10/site-packages (from pydantic>=2.0->dgl) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/mlcore/conda/lib/python3.10/site-packages (from requests>=2.19.0->dgl) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in /home/mlcore/conda/lib/python3.10/site-packages (from requests>=2.19.0->dgl) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in /home/mlcore/.local/lib/python3.10/site-packages (from requests>=2.19.0->dgl) (1.26.20)
# Requirement already satisfied: certifi>=2023.5.7 in /home/mlcore/conda/lib/python3.10/site-packages (from requests>=2.19.0->dgl) (2026.2.25)
# Requirement already satisfied: filelock in /home/mlcore/conda/lib/python3.10/site-packages (from torch<=2.4.0->dgl) (3.25.1)
# Requirement already satisfied: sympy in /home/mlcore/conda/lib/python3.10/site-packages (from torch<=2.4.0->dgl) (1.14.0)
# Requirement already satisfied: jinja2 in /home/mlcore/.local/lib/python3.10/site-packages (from torch<=2.4.0->dgl) (3.1.6)
# Requirement already satisfied: fsspec in /home/mlcore/.local/lib/python3.10/site-packages (from torch<=2.4.0->dgl) (2026.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/mlcore/conda/lib/python3.10/site-packages (from torch<=2.4.0->dgl) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/mlcore/conda/lib/python3.10/site-packages (from torch<=2.4.0->dgl) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/mlcore/conda/lib/python3.10/site-packages (from torch<=2.4.0->dgl) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/mlcore/conda/lib/python3.10/site-packages (from torch<=2.4.0->dgl) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/mlcore/conda/lib/python3.10/site-packages (from torch<=2.4.0->dgl) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/mlcore/conda/lib/python3.10/site-packages (from torch<=2.4.0->dgl) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/mlcore/conda/lib/python3.10/site-packages (from torch<=2.4.0->dgl) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/mlcore/conda/lib/python3.10/site-packages (from torch<=2.4.0->dgl) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/mlcore/conda/lib/python3.10/site-packages (from torch<=2.4.0->dgl) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /home/mlcore/conda/lib/python3.10/site-packages (from torch<=2.4.0->dgl) (2.18.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/mlcore/conda/lib/python3.10/site-packages (from torch<=2.4.0->dgl) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in /home/mlcore/conda/lib/python3.10/site-packages (from torch<=2.4.0->dgl) (2.1.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/mlcore/conda/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch<=2.4.0->dgl) (12.9.86)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/mlcore/conda/lib/python3.10/site-packages (from pandas->dgl) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/mlcore/conda/lib/python3.10/site-packages (from pandas->dgl) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in /home/mlcore/conda/lib/python3.10/site-packages (from pandas->dgl) (2025.3)
# Requirement already satisfied: six>=1.5 in /home/mlcore/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->dgl) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/mlcore/.local/lib/python3.10/site-packages (from jinja2->torch<=2.4.0->dgl) (3.0.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/mlcore/conda/lib/python3.10/site-packages (from sympy->torch<=2.4.0->dgl) (1.3.0)
#
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python3.10 -m pip install --upgrade pip
# Looking in indexes: https://artifactory.tcsbank.ru/artifactory/api/pypi/python-all/simple
# Requirement already satisfied: scikit-learn in /home/mlcore/conda/lib/python3.10/site-packages (1.7.2)
# Requirement already satisfied: numpy>=1.22.0 in /home/mlcore/conda/lib/python3.10/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.8.0 in /home/mlcore/conda/lib/python3.10/site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /home/mlcore/conda/lib/python3.10/site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/mlcore/conda/lib/python3.10/site-packages (from scikit-learn) (3.6.0)
#
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python3.10 -m pip install --upgrade pip
# Looking in indexes: https://artifactory.tcsbank.ru/artifactory/api/pypi/python-all/simple
# Requirement already satisfied: fasttext==0.9.2 in /home/mlcore/conda/lib/python3.10/site-packages (0.9.2)
# Requirement already satisfied: pybind11>=2.2 in /home/mlcore/conda/lib/python3.10/site-packages (from fasttext==0.9.2) (3.0.3)
# Requirement already satisfied: setuptools>=0.7.0 in /home/mlcore/.local/lib/python3.10/site-packages (from fasttext==0.9.2) (80.10.2)
# Requirement already satisfied: numpy in /home/mlcore/conda/lib/python3.10/site-packages (from fasttext==0.9.2) (1.26.4)
#
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python3.10 -m pip install --upgrade pip

# %%
from argparse import Namespace
from pathlib import Path

import dgl
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch
from sklearn.metrics import classification_report, confusion_matrix
from torch.utils.data import DataLoader

from core.model.MainModel import MainModel
from prepare_data import prepare_for_graphormer
from process.EventProcess import EventProcess

plt.rcParams['figure.figsize'] = (10, 8)
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_colwidth', 120)

# %%
DATASET = 'gaia'
LABELS_FILE = 'gaia.csv'
CHECKPOINT_PATH = Path('logs') / DATASET / 'corrected_index_data_trained_model_gaia.pt'
# ONLY_METRICS_CHECKPOINT_PATH = Path('logs') / DATASET / 'TransTVDiag-metric.pt'
# ONLY_LOGS_CHECKPOINT_PATH = Path('logs') / DATASET / 'TransTVDiag-log.pt'
# ONLY_TRACES_CHECKPOINT_PATH = Path('logs') / DATASET / 'TransTVDiag-trace.pt'
OUTPUT_DIR = Path('logs') / DATASET / 'evaluation_artifacts'
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'

import pickle
labels_df = pd.read_csv(Path('data') / DATASET / LABELS_FILE)
instance_names = sorted(list(set(list(labels_df['instance']))))
failure_type_names = sorted(list((set(list(labels_df['anomaly_type'])))))

print('inctance num', len(instance_names))
print('failure type num', len(failure_type_names))
print('-------')
instance_id_to_name = {idx: name for idx, name in enumerate(instance_names)}
failure_type_id_to_name = {idx: name for idx, name in enumerate(failure_type_names)}

test_meta = labels_df[labels_df['data_type'] == 'test'].reset_index(drop=True).copy()
print('Test samples:', len(test_meta))
print('Instance labels:', instance_id_to_name)
print('Failure type labels:', failure_type_id_to_name)
# print('-------')

args = Namespace(
    dataset=DATASET,
    labels_file=LABELS_FILE,
    embedding_dim=128,
    graph_hidden=128,
    graph_out=32,
    num_heads=16,
    num_layers=2,
    attn_drop=0.0,
    linear_hidden=[64],
    reconstruct=True,
    aug_percent=0.2,
    N_I = len(instance_names),
    N_T = len(failure_type_names),
    root_loss = 'ce',
    type_loss = 'ce',
    focal_gamma = 0.5
)

print(args)
print('-------')

OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
print(f'Device: {DEVICE}')
print(f'Checkpoint: {CHECKPOINT_PATH.resolve()}')
print(f'Artifacts dir: {OUTPUT_DIR.resolve()}')
# Out:
# inctance num 10
# failure type num 5
# -------
# Test samples: 13774
# Instance labels: {0: 'dbservice1', 1: 'dbservice2', 2: 'logservice1', 3: 'logservice2', 4: 'mobservice1', 5: 'mobservice2', 6: 'redisservice1', 7: 'redisservice2', 8: 'webservice1', 9: 'webservice2'}
# Failure type labels: {0: '[access permission denied exception]', 1: '[file moving program]', 2: '[login failure]', 3: '[memory_anomalies]', 4: '[normal memory freed label]'}
# Namespace(dataset='gaia', labels_file='gaia.csv', embedding_dim=128, graph_hidden=128, graph_out=32, num_heads=16, num_layers=2, attn_drop=0.0, linear_hidden=[64], reconstruct=True, aug_percent=0.2, N_I=10, N_T=5, root_loss='ce', type_loss='ce', focal_gamma=0.5)
# -------
# Device: cuda
# Checkpoint: /workdir/TransTVDiag/logs/gaia/corrected_index_data_trained_model_gaia.pt
# Artifacts dir: /workdir/TransTVDiag/logs/gaia/evaluation_artifacts

# %%
# import pickle
# labels_df = pd.read_csv(Path('data') / DATASET / LABELS_FILE)
# instance_names = sorted(list(set(list(labels_df['instance']))))
# failure_type_names = sorted(list((set(list(labels_df['anomaly_type'])))))
# sorted(labels_df['anomaly_type'].unique().tolist())
# with open('data/gaia/events/nodes.pkl', 'rb') as f:
#         instance_names = pickle.load(f, encoding='bytes')
# # labels = pd.read_csv(label_path)
# failure_type_names = ['normal'] + labels_df['anomaly_type'].unique().tolist()

# args.N_I = len(instance_names)
# args.N_T = len(failure_type_names)
# print('inctance num', len(instance_names))
# print('failure type num', len(failure_type_names))
# print('-------')
# print(args)
# print('-------')


# instance_id_to_name = {idx: name for idx, name in enumerate(instance_names)}
# failure_type_id_to_name = {idx: name for idx, name in enumerate(failure_type_names)}

# test_meta = labels_df[labels_df['data_type'] == 'test'].reset_index(drop=True).copy()
# print('Test samples:', len(test_meta))
# print('Instance labels:', instance_id_to_name)
# print('Failure type labels:', failure_type_id_to_name)

# %%
class NotebookLogger:
    def info(self, msg):
        pass
    def debug(self, msg):
        pass

def collate(samples):
    graphs, labels = map(list, zip(*samples))
    labels = torch.tensor(labels)
    return prepare_for_graphormer(graphs, labels)

processor = EventProcess(args, NotebookLogger())
_, test_data = processor.process(reconstruct=False)
test_loader = DataLoader(test_data, batch_size=1, shuffle=False, collate_fn=collate)

len(test_data)
# Out:
# 13774

# %%
import torch
import pandas as pd


def build_predictions_df(
    args,
    CHECKPOINT_PATH,
    test_loader,
    test_meta,
    instance_names,
    failure_type_names,
    instance_id_to_name,
    failure_type_id_to_name,
    MainModel,
    DEVICE,
):
    model = MainModel(args).to(DEVICE)
    checkpoint = torch.load(CHECKPOINT_PATH, map_location=DEVICE)
    model.load_state_dict(checkpoint["model"])
    model.eval()

    records = []

    for sample_idx, batch in enumerate(test_loader):
        (
            labels,
            metric_feat,
            trace_feat,
            log_feat,
            in_degree,
            out_degree,
            attn_mask,
            path_data,
            dist,
        ) = batch

        target_root_idx = labels[:, 0].item()
        target_type_idx = labels[:, 1].item()

        with torch.no_grad():
            _, root_logits, type_logits = model(
                metric_feat.to(DEVICE),
                trace_feat.to(DEVICE),
                log_feat.to(DEVICE),
                in_degree.to(DEVICE),
                out_degree.to(DEVICE),
                dist.to(DEVICE),
                path_data.to(DEVICE),
                attn_mask.to(DEVICE),
            )

        root_probs = torch.softmax(root_logits, dim=1).cpu()[0]
        type_probs = torch.softmax(type_logits, dim=1).cpu()[0]

        pred_root_idx = int(root_probs.argmax().item())
        pred_type_idx = int(type_probs.argmax().item())

        topk_root = min(5, len(instance_names))
        root_topk_scores, root_topk_indices = torch.topk(root_probs, k=topk_root)
        type_topk_scores, type_topk_indices = torch.topk(
            type_probs, k=len(failure_type_names)
        )

        meta = test_meta.iloc[sample_idx]
        records.append(
            {
                "sample_position": sample_idx,
                "data_index": int(meta["index"]),
                "datetime": meta["datetime"],
                "service": meta["service"],
                "message": meta["message"],
                "target_root_idx": target_root_idx,
                "target_root_name": instance_id_to_name[target_root_idx],
                "pred_root_idx": pred_root_idx,
                "pred_root_name": instance_id_to_name[pred_root_idx],
                "target_type_idx": target_type_idx,
                "target_type_name": failure_type_id_to_name[target_type_idx],
                "pred_type_idx": pred_type_idx,
                "pred_type_name": failure_type_id_to_name[pred_type_idx],
                "root_correct": pred_root_idx == target_root_idx,
                "type_correct": pred_type_idx == target_type_idx,
                "pred_root_confidence": float(root_probs[pred_root_idx].item()),
                "pred_type_confidence": float(type_probs[pred_type_idx].item()),
                "root_top5_indices": [int(x) for x in root_topk_indices.tolist()],
                "root_top5_names": [
                    instance_id_to_name[int(x)] for x in root_topk_indices.tolist()
                ],
                "root_top5_scores": [float(x) for x in root_topk_scores.tolist()],
                "type_ranked_indices": [int(x) for x in type_topk_indices.tolist()],
                "type_ranked_names": [
                    failure_type_id_to_name[int(x)] for x in type_topk_indices.tolist()
                ],
                "type_ranked_scores": [float(x) for x in type_topk_scores.tolist()],
            }
        )

    predictions_df = pd.DataFrame(records)
    return predictions_df

# %%
predictions_df = build_predictions_df(
    args=args,
    CHECKPOINT_PATH=CHECKPOINT_PATH,
    test_loader=test_loader,
    test_meta=test_meta,
    instance_names=instance_names,
    failure_type_names=failure_type_names,
    instance_id_to_name=instance_id_to_name,
    failure_type_id_to_name=failure_type_id_to_name,
    MainModel=MainModel,
    DEVICE=DEVICE,
)

predictions_df.head()
# Out:
# From Main Model:  {'log', 'metric', 'trace'}
# Root loss:  ce fault type loss:  ce
#    sample_position  data_index    datetime     service  \
# 0                0        1980  2021-07-05  webservice
# 1                1        2203  2021-07-05  mobservice
# 2                2        2204  2021-07-05  mobservice
# 3                3        2205  2021-07-05  mobservice
# 4                4        2206  2021-07-05  mobservice
#
#                                                                                                                    message  \
# 0  2021-07-05 22:09:15,582 | WARNING | 0.0.0.1 | 172.17.0.3 | webservice1 | [memory_anomalies] trigger a high memory pr...
# 1  2021-07-05 21:42:32,616 | WARNING | 0.0.0.4 | 172.17.0.2 | mobservice2 | b13e6cdef1c77e0f | wait for 11 seconds for ...
# 2  2021-07-05 21:50:37,731 | WARNING | 0.0.0.4 | 172.17.0.2 | mobservice2 | 286d315a73923371 | wait for 11 seconds for ...
# 3  2021-07-05 21:56:26,911 | WARNING | 0.0.0.4 | 172.17.0.2 | mobservice2 | b1eeed119a0ffca5 | wait for 11 seconds for ...
# 4  2021-07-05 22:06:04,641 | WARNING | 0.0.0.4 | 172.17.0.2 | mobservice2 | 1a06c7b08f348618 | wait for 11 seconds for ...
#
#    target_root_idx target_root_name  pred_root_idx pred_root_name  \
# 0                8      webservice1              6  redisservice1
# 1                5      mobservice2              5    mobservice2
# 2                5      mobservice2              4    mobservice1
# 3                5      mobservice2              5    mobservice2
# 4                5      mobservice2              5    mobservice2
#
#    target_type_idx    target_type_name  pred_type_idx      pred_type_name  \
# 0                3  [memory_anomalies]              3  [memory_anomalies]
# 1                2     [login failure]              2     [login failure]
# 2                2     [login failure]              2     [login failure]
# 3                2     [login failure]              2     [login failure]
# 4                2     [login failure]              2     [login failure]
#
#    root_correct  type_correct  pred_root_confidence  pred_type_confidence  \
# 0         False          True              0.409939              0.999998
# 1          True          True              0.999980              0.999995
# 2         False          True              0.646767              0.999957
# 3          True          True              0.999994              0.999991
# 4          True          True              0.999982              0.999997
#
#   root_top5_indices  \
# 0   [6, 3, 2, 7, 1]
# 1   [5, 4, 2, 3, 9]
# 2   [4, 5, 1, 0, 2]
# 3   [5, 4, 2, 0, 9]
# 4   [5, 4, 2, 3, 9]
#
#                                                         root_top5_names  \
# 0  [redisservice1, logservice2, logservice1, redisservice2, dbservice2]
# 1     [mobservice2, mobservice1, logservice1, logservice2, webservice2]
# 2       [mobservice1, mobservice2, dbservice2, dbservice1, logservice1]
# 3      [mobservice2, mobservice1, logservice1, dbservice1, webservice2]
# 4     [mobservice2, mobservice1, logservice1, logservice2, webservice2]
#
#                                                                                                      root_top5_scores  \
# 0           [0.40993940830230713, 0.2619327902793884, 0.24566161632537842, 0.04963552951812744, 0.017835889011621475]
# 1   [0.9999804496765137, 1.741652340569999e-05, 1.28187252812495e-06, 3.1968053804121155e-07, 2.4406867282777966e-07]
# 2    [0.646767258644104, 0.35214707255363464, 0.00026880879886448383, 0.00018775431090034544, 0.00017261868924833834]
# 3     [0.999994158744812, 4.85500004288042e-06, 7.635398446836916e-07, 1.1872283067759781e-07, 6.513991479550896e-08]
# 4  [0.9999818801879883, 1.6002561096684076e-05, 1.138078118856356e-06, 3.893982807312568e-07, 3.2554220297242864e-07]
#
#   type_ranked_indices  \
# 0     [3, 4, 1, 0, 2]
# 1     [2, 3, 4, 0, 1]
# 2     [2, 3, 4, 0, 1]
# 3     [2, 3, 4, 0, 1]
# 4     [2, 3, 4, 0, 1]
#
#                                                                                                          type_ranked_names  \
# 0  [[memory_anomalies], [normal memory freed label], [file moving program], [access permission denied exception], [logi...
# 1  [[login failure], [memory_anomalies], [normal memory freed label], [access permission denied exception], [file movin...
# 2  [[login failure], [memory_anomalies], [normal memory freed label], [access permission denied exception], [file movin...
# 3  [[login failure], [memory_anomalies], [normal memory freed label], [access permission denied exception], [file movin...
# 4  [[login failure], [memory_anomalies], [normal memory freed label], [access permission denied exception], [file movin...
#
#                                                                                                   type_ranked_scores
# 0    [0.9999978542327881, 2.004277121159248e-06, 9.800972833318156e-08, 4.84590536586893e-08, 4.652789709069793e-09]
# 1   [0.9999954700469971, 2.5709782676131e-06, 1.1099955372628756e-06, 6.405214776350476e-07, 2.1683145234874246e-07]
# 2  [0.9999570846557617, 1.7356936950818636e-05, 1.104873535950901e-05, 9.413828593096696e-06, 5.080569280835334e-06]
# 3  [0.9999908208847046, 4.902263754047453e-06, 2.332418944206438e-06, 1.3668500287167262e-06, 5.278498065308668e-07]
# 4   [0.9999970197677612, 1.6858291473909048e-06, 7.65291645166144e-07, 3.868977671572793e-07, 1.313965185545385e-07]

# %%
# model = MainModel(args).to(DEVICE)
# checkpoint = torch.load(CHECKPOINT_PATH, map_location=DEVICE)
# model.load_state_dict(checkpoint['model'])
# model.eval()

# records = []

# for sample_idx, batch in enumerate(test_loader):
#     labels, metric_feat, trace_feat, log_feat, in_degree, out_degree, attn_mask, path_data, dist = batch

#     target_root_idx = labels[:, 0].item()
#     target_type_idx = labels[:, 1].item()

#     with torch.no_grad():
#         _, root_logits, type_logits = model(
#             metric_feat.to(DEVICE),
#             trace_feat.to(DEVICE),
#             log_feat.to(DEVICE),
#             in_degree.to(DEVICE),
#             out_degree.to(DEVICE),
#             dist.to(DEVICE),
#             path_data.to(DEVICE),
#             attn_mask.to(DEVICE),
#         )

#     root_probs = torch.softmax(root_logits, dim=1).cpu()[0]
#     type_probs = torch.softmax(type_logits, dim=1).cpu()[0]

#     pred_root_idx = int(root_probs.argmax().item())
#     pred_type_idx = int(type_probs.argmax().item())

#     topk_root = min(5, len(instance_names))
#     root_topk_scores, root_topk_indices = torch.topk(root_probs, k=topk_root)
#     type_topk_scores, type_topk_indices = torch.topk(type_probs, k=len(failure_type_names))

#     meta = test_meta.iloc[sample_idx]
#     records.append({
#         'sample_position': sample_idx,
#         'data_index': int(meta['index']),
#         'datetime': meta['datetime'],
#         'service': meta['service'],
#         'message': meta['message'],
#         'target_root_idx': target_root_idx,
#         'target_root_name': instance_id_to_name[target_root_idx],
#         'pred_root_idx': pred_root_idx,
#         'pred_root_name': instance_id_to_name[pred_root_idx],
#         'target_type_idx': target_type_idx,
#         'target_type_name': failure_type_id_to_name[target_type_idx],
#         'pred_type_idx': pred_type_idx,
#         'pred_type_name': failure_type_id_to_name[pred_type_idx],
#         'root_correct': pred_root_idx == target_root_idx,
#         'type_correct': pred_type_idx == target_type_idx,
#         'pred_root_confidence': float(root_probs[pred_root_idx].item()),
#         'pred_type_confidence': float(type_probs[pred_type_idx].item()),
#         'root_top5_indices': [int(x) for x in root_topk_indices.tolist()],
#         'root_top5_names': [instance_id_to_name[int(x)] for x in root_topk_indices.tolist()],
#         'root_top5_scores': [float(x) for x in root_topk_scores.tolist()],
#         'type_ranked_indices': [int(x) for x in type_topk_indices.tolist()],
#         'type_ranked_names': [failure_type_id_to_name[int(x)] for x in type_topk_indices.tolist()],
#         'type_ranked_scores': [float(x) for x in type_topk_scores.tolist()],
#     })

# predictions_df = pd.DataFrame(records)
# predictions_df.head()
# Out:
# From Main Model:  {'log', 'trace', 'metric'}
#    sample_position  data_index    datetime     service  \
# 0                0        2431  2021-07-05  mobservice
# 1                1        2432  2021-07-05  mobservice
# 2                2        2433  2021-07-05  mobservice
# 3                3        2434  2021-07-05  mobservice
# 4                4        2435  2021-07-05  mobservice
#
#                                                                                                                    message  \
# 0  2021-07-05 21:42:01,380 | WARNING | 0.0.0.1 | 172.17.0.5 | mobservice1 | 86ec9abb15b5ff80 | wait for 11 seconds for ...
# 1  2021-07-05 21:42:32,616 | WARNING | 0.0.0.4 | 172.17.0.2 | mobservice2 | b13e6cdef1c77e0f | wait for 11 seconds for ...
# 2  2021-07-05 21:45:00,329 | WARNING | 0.0.0.1 | 172.17.0.5 | mobservice1 | 5930623f2070d5ba | wait for 11 seconds for ...
# 3  2021-07-05 21:49:00,904 | WARNING | 0.0.0.1 | 172.17.0.5 | mobservice1 | 2375b8b74da928f8 | wait for 11 seconds for ...
# 4  2021-07-05 21:50:37,731 | WARNING | 0.0.0.4 | 172.17.0.2 | mobservice2 | 286d315a73923371 | wait for 11 seconds for ...
#
#    target_root_idx target_root_name  pred_root_idx pred_root_name  \
# 0                4      mobservice1              4    mobservice1
# 1                5      mobservice2              5    mobservice2
# 2                4      mobservice1              4    mobservice1
# 3                4      mobservice1              4    mobservice1
# 4                5      mobservice2              4    mobservice1
#
#    target_type_idx target_type_name  pred_type_idx   pred_type_name  \
# 0                2  [login failure]              2  [login failure]
# 1                2  [login failure]              2  [login failure]
# 2                2  [login failure]              2  [login failure]
# 3                2  [login failure]              2  [login failure]
# 4                2  [login failure]              2  [login failure]
#
#    root_correct  type_correct  pred_root_confidence  pred_type_confidence  \
# 0          True          True              0.999914              0.999994
# 1          True          True              0.999997              0.999998
# 2          True          True              0.999855              0.999951
# 3          True          True              0.999978              0.999968
# 4         False          True              0.999655              0.999847
#
#   root_top5_indices  \
# 0   [4, 5, 8, 7, 0]
# 1   [5, 4, 3, 6, 9]
# 2   [4, 5, 8, 7, 0]
# 3   [4, 5, 8, 0, 7]
# 4   [4, 5, 8, 0, 7]
#
#                                                        root_top5_names  \
# 0   [mobservice1, mobservice2, webservice1, redisservice2, dbservice1]
# 1  [mobservice2, mobservice1, logservice2, redisservice1, webservice2]
# 2   [mobservice1, mobservice2, webservice1, redisservice2, dbservice1]
# 3   [mobservice1, mobservice2, webservice1, dbservice1, redisservice2]
# 4   [mobservice1, mobservice2, webservice1, dbservice1, redisservice2]
#
#                                                                                                      root_top5_scores  \
# 0    [0.999914288520813, 6.592032877961174e-05, 8.936001904658042e-06, 3.4809122553269845e-06, 2.916104222094873e-06]
# 1  [0.9999972581863403, 2.058532572846161e-06, 3.6665318248196854e-07, 1.0296923136365876e-07, 8.610887647364507e-08]
# 2  [0.9998552799224854, 7.668261969229206e-05, 2.8311780624790117e-05, 1.3509931704902556e-05, 1.091548620024696e-05]
# 3  [0.9999775886535645, 8.348110895894933e-06, 5.1018041631323285e-06, 2.7101214072899893e-06, 2.394256853222032e-06]
# 4     [0.99965500831604, 0.0001422630448359996, 9.129815589403734e-05, 3.451359225437045e-05, 2.8413534892024472e-05]
#
#   type_ranked_indices  \
# 0     [2, 0, 1, 4, 3]
# 1     [2, 3, 4, 0, 1]
# 2     [2, 1, 0, 4, 3]
# 3     [2, 1, 0, 4, 3]
# 4     [2, 1, 0, 4, 3]
#
#                                                                                                          type_ranked_names  \
# 0  [[login failure], [access permission denied exception], [file moving program], [normal memory freed label], [memory_...
# 1  [[login failure], [memory_anomalies], [normal memory freed label], [access permission denied exception], [file movin...
# 2  [[login failure], [file moving program], [access permission denied exception], [normal memory freed label], [memory_...
# 3  [[login failure], [file moving program], [access permission denied exception], [normal memory freed label], [memory_...
# 4  [[login failure], [file moving program], [access permission denied exception], [normal memory freed label], [memory_...
#
#                                                                                                     type_ranked_scores
# 0  [0.9999939203262329, 1.618591568330885e-06, 1.6151838053701795e-06, 1.5698478819103912e-06, 1.2171112757641822e-06]
# 1      [0.9999979734420776, 8.179923725037952e-07, 5.073641773378768e-07, 5.02759974096989e-07, 2.293502632255695e-07]
# 2   [0.9999514818191528, 1.5133462511585094e-05, 1.2504715414252132e-05, 1.180701201519696e-05, 9.104664059123024e-06]
# 3     [0.9999679327011108, 9.020796824188437e-06, 8.656033969600685e-06, 7.766770067973994e-06, 6.609557203773875e-06]
# 4      [0.9998469352722168, 4.387031731312163e-05, 4.11245200666599e-05, 3.510763417580165e-05, 3.293188274255954e-05]

# %%
predictions_csv = OUTPUT_DIR / 'test_predictions.csv'
predictions_parquet = OUTPUT_DIR / 'test_predictions.parquet'

predictions_df.to_csv(predictions_csv, index=False)
print(f'Saved: {predictions_csv.resolve()}')

# try:
#     predictions_df.to_parquet(predictions_parquet, index=False)
#     print(f'Saved: {predictions_parquet.resolve()}')
# except Exception as exc:
#     print(f'Parquet export skipped: {exc}')
# Out:
# Saved: /workdir/TransTVDiag/logs/gaia/evaluation_artifacts/test_predictions.csv

# %%
root_report = classification_report(
    predictions_df['target_root_name'],
    predictions_df['pred_root_name'],
    labels=instance_names,
    output_dict=True,
    zero_division=0,
)
type_report = classification_report(
    predictions_df['target_type_name'],
    predictions_df['pred_type_name'],
    labels=failure_type_names,
    output_dict=True,
    zero_division=0,
)

root_report_df = pd.DataFrame(root_report).transpose()
type_report_df = pd.DataFrame(type_report).transpose()

root_report_df.to_csv(OUTPUT_DIR / 'classification_report_rcl.csv')
type_report_df.to_csv(OUTPUT_DIR / 'classification_report_fti.csv')

display(root_report_df)
display(type_report_df)
# Out:
#                precision    recall  f1-score       support
# dbservice1      0.106195  0.173913  0.131868     69.000000
# dbservice2      0.120690  0.080460  0.096552     87.000000
# logservice1     0.064815  0.127273  0.085890     55.000000
# logservice2     0.035714  0.019608  0.025316     51.000000
# mobservice1     0.915651  0.850287  0.881759   6626.000000
# mobservice2     0.869303  0.910954  0.889641   6637.000000
# redisservice1   0.072464  0.106383  0.086207     47.000000
# redisservice2   0.058394  0.166667  0.086486     48.000000
# webservice1     0.125000  0.012821  0.023256     78.000000
# webservice2     0.048276  0.092105  0.063348     76.000000
# accuracy        0.851459  0.851459  0.851459      0.851459
# macro avg       0.241650  0.254047  0.237032  13774.000000
# weighted avg    0.862459  0.851459  0.855629  13774.000000
#                                       precision    recall  f1-score  \
# [access permission denied exception]   0.000000  0.000000  0.000000
# [file moving program]                  0.034483  0.027027  0.030303
# [login failure]                        0.999211  0.964087  0.981335
# [memory_anomalies]                     0.515551  0.969858  0.673231
# [normal memory freed label]            0.000000  0.000000  0.000000
# accuracy                               0.959707  0.959707  0.959707
# macro avg                              0.309849  0.392195  0.336974
# weighted avg                           0.974639  0.959707  0.964027
#
#                                            support
# [access permission denied exception]     15.000000
# [file moving program]                    37.000000
# [login failure]                       13143.000000
# [memory_anomalies]                      564.000000
# [normal memory freed label]              15.000000
# accuracy                                  0.959707
# macro avg                             13774.000000
# weighted avg                          13774.000000

# %%
print('RCL report')
print(classification_report(
    predictions_df['target_root_name'],
    predictions_df['pred_root_name'],
    labels=instance_names,
    zero_division=0,
))

print('FTI report')
print(classification_report(
    predictions_df['target_type_name'],
    predictions_df['pred_type_name'],
    labels=failure_type_names,
    zero_division=0,
))
# Out:
# RCL report
#                precision    recall  f1-score   support
#
#    dbservice1       0.11      0.17      0.13        69
#    dbservice2       0.12      0.08      0.10        87
#   logservice1       0.06      0.13      0.09        55
#   logservice2       0.04      0.02      0.03        51
#   mobservice1       0.92      0.85      0.88      6626
#   mobservice2       0.87      0.91      0.89      6637
# redisservice1       0.07      0.11      0.09        47
# redisservice2       0.06      0.17      0.09        48
#   webservice1       0.12      0.01      0.02        78
#   webservice2       0.05      0.09      0.06        76
#
#      accuracy                           0.85     13774
#     macro avg       0.24      0.25      0.24     13774
#  weighted avg       0.86      0.85      0.86     13774
#
# FTI report
#                                       precision    recall  f1-score   support
#
# [access permission denied exception]       0.00      0.00      0.00        15
#                [file moving program]       0.03      0.03      0.03        37
#                      [login failure]       1.00      0.96      0.98     13143
#                   [memory_anomalies]       0.52      0.97      0.67       564
#          [normal memory freed label]       0.00      0.00      0.00        15
#
#                             accuracy                           0.96     13774
#                            macro avg       0.31      0.39      0.34     13774
#                         weighted avg       0.97      0.96      0.96     13774

# %%
def plot_confusion_matrix(cm, labels, title, rotate_x=45):
    fig, ax = plt.subplots(figsize=(10, 8))
    im = ax.imshow(cm, interpolation='nearest', cmap='Blues')
    ax.figure.colorbar(im, ax=ax)
    ax.set(
        xticks=np.arange(len(labels)),
        yticks=np.arange(len(labels)),
        xticklabels=labels,
        yticklabels=labels,
        title=title,
        ylabel='True label',
        xlabel='Predicted label',
    )
    plt.setp(ax.get_xticklabels(), rotation=rotate_x, ha='right', rotation_mode='anchor')

    threshold = cm.max() / 2.0 if cm.size else 0
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(
                j,
                i,
                format(cm[i, j], 'd'),
                ha='center',
                va='center',
                color='white' if cm[i, j] > threshold else 'black',
            )
    fig.tight_layout()
    return fig

# %%
root_cm = confusion_matrix(
    predictions_df['target_root_name'],
    predictions_df['pred_root_name'],
    labels=instance_names,
)
type_cm = confusion_matrix(
    predictions_df['target_type_name'],
    predictions_df['pred_type_name'],
    labels=failure_type_names,
)

pd.DataFrame(root_cm, index=instance_names, columns=instance_names).to_csv(OUTPUT_DIR / 'confusion_matrix_rcl.csv')
pd.DataFrame(type_cm, index=failure_type_names, columns=failure_type_names).to_csv(OUTPUT_DIR / 'confusion_matrix_fti.csv')

fig_root = plot_confusion_matrix(root_cm, instance_names, 'RCL Confusion Matrix')
fig_type = plot_confusion_matrix(type_cm, failure_type_names, 'FTI Confusion Matrix', rotate_x=25)

fig_root.savefig(OUTPUT_DIR / 'confusion_matrix_rcl.png', bbox_inches='tight')
fig_type.savefig(OUTPUT_DIR / 'confusion_matrix_fti.png', bbox_inches='tight')
plt.show()

# %%
summary = pd.DataFrame([
    {
        'task': 'RCL',
        'accuracy': (predictions_df['target_root_name'] == predictions_df['pred_root_name']).mean(),
        'macro_f1': root_report_df.loc['macro avg', 'f1-score'],
        'weighted_f1': root_report_df.loc['weighted avg', 'f1-score'],
    },
    {
        'task': 'FTI',
        'accuracy': (predictions_df['target_type_name'] == predictions_df['pred_type_name']).mean(),
        'macro_f1': type_report_df.loc['macro avg', 'f1-score'],
        'weighted_f1': type_report_df.loc['weighted avg', 'f1-score'],
    },
])

summary.to_csv(OUTPUT_DIR / 'metrics_summary.csv', index=False)
summary
# Out:
#   task  accuracy  macro_f1  weighted_f1
# 0  RCL  0.853637  0.239741     0.853506
# 1  FTI  0.993248  0.454602     0.992577

# %% [markdown]
# ## Without mobservice

# %%
LABELS_FILE_WITHOUT_MOBSERVICE = 'gaia_without_mobservice.csv'
CHECKPOINT_PATH_WITHOUT_MOBSERVICE = Path('logs') / DATASET / 'corrected_index_data_trained_model_without_modservice_gaia.pt'

import pickle
labels_df = pd.read_csv(Path('data') / DATASET / LABELS_FILE_WITHOUT_MOBSERVICE)
instance_names = sorted(list(set(list(labels_df['instance']))))
failure_type_names = sorted(list((set(list(labels_df['anomaly_type'])))))

print('inctance num', len(instance_names))
print('failure type num', len(failure_type_names))
print('-------')
print(args)
print('-------')

instance_id_to_name = {idx: name for idx, name in enumerate(instance_names)}
failure_type_id_to_name = {idx: name for idx, name in enumerate(failure_type_names)}

test_meta = labels_df[labels_df['data_type'] == 'test'].reset_index(drop=True).copy()
print('Test samples:', len(test_meta))
print('Instance labels:', instance_id_to_name)
print('Failure type labels:', failure_type_id_to_name)
# print('-------')

args = Namespace(
    dataset=DATASET,
    labels_file=LABELS_FILE_WITHOUT_MOBSERVICE,
    embedding_dim=128,
    graph_hidden=128,
    graph_out=32,
    num_heads=16,
    num_layers=2,
    attn_drop=0.0,
    linear_hidden=[64],
    reconstruct=True,
    aug_percent=0.2,
    N_I = len(instance_names),
    N_T = len(failure_type_names),
    root_loss = 'ce',
    type_loss = 'ce',
    focal_gamma = 0.5
)


OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
print(f'Device: {DEVICE}')
print(f'Checkpoint: {CHECKPOINT_PATH_WITHOUT_MOBSERVICE.resolve()}')
print(f'Artifacts dir: {OUTPUT_DIR.resolve()}')
# Out:
# inctance num 8
# failure type num 4
# -------
# Namespace(dataset='gaia', labels_file='label_without_mobservice.csv', embedding_dim=128, graph_hidden=128, graph_out=32, num_heads=16, num_layers=2, attn_drop=0.0, linear_hidden=[64], reconstruct=True, aug_percent=0.2, N_I=8, N_T=4, root_loss='ce', type_loss='ce', focal_gamma=0.5)
# -------
# Test samples: 511
# Instance labels: {0: 'dbservice1', 1: 'dbservice2', 2: 'logservice1', 3: 'logservice2', 4: 'redisservice1', 5: 'redisservice2', 6: 'webservice1', 7: 'webservice2'}
# Failure type labels: {0: '[access permission denied exception]', 1: '[file moving program]', 2: '[memory_anomalies]', 3: '[normal memory freed label]'}
# Device: cuda
# Checkpoint: /workdir/TransTVDiag/logs/gaia/corrected_index_data_trained_model_without_modservice_gaia.pt
# Artifacts dir: /workdir/TransTVDiag/logs/gaia/evaluation_artifacts

# %%
class NotebookLogger:
    def info(self, msg):
        pass
    def debug(self, msg):
        pass

def collate(samples):
    graphs, labels = map(list, zip(*samples))
    labels = torch.tensor(labels)
    return prepare_for_graphormer(graphs, labels)

processor = EventProcess(args, NotebookLogger())
_, test_data = processor.process(reconstruct=False)
test_loader = DataLoader(test_data, batch_size=1, shuffle=False, collate_fn=collate)

len(test_data)
# Out:
# 511

# %%
predictions_without_mobservice_df = build_predictions_df(
    args=args,
    CHECKPOINT_PATH=CHECKPOINT_PATH_WITHOUT_MOBSERVICE,
    test_loader=test_loader,
    test_meta=test_meta,
    instance_names=instance_names,
    failure_type_names=failure_type_names,
    instance_id_to_name=instance_id_to_name,
    failure_type_id_to_name=failure_type_id_to_name,
    MainModel=MainModel,
    DEVICE=DEVICE,
)

predictions_without_mobservice_df.head()
# Out:
# From Main Model:  {'log', 'metric', 'trace'}
# Root loss:  ce fault type loss:  ce
#    sample_position  data_index    datetime     service  \
# 0                0        1980  2021-07-05  webservice
# 1                1        2485  2021-07-06   dbservice
# 2                2        2486  2021-07-06   dbservice
# 3                3        2487  2021-07-06   dbservice
# 4                4        2488  2021-07-06   dbservice
#
#                                                                                                                    message  \
# 0  2021-07-05 22:09:15,582 | WARNING | 0.0.0.1 | 172.17.0.3 | webservice1 | [memory_anomalies] trigger a high memory pr...
# 1  2021-07-06 13:41:25,597 | WARNING | 0.0.0.4 | 172.17.0.3 | dbservice1 | [memory_anomalies] trigger a high memory pro...
# 2  2021-07-06 14:49:17,645 | WARNING | 0.0.0.4 | 172.17.0.3 | dbservice1 | [memory_anomalies] trigger a high memory pro...
# 3  2021-07-06 09:35:39,440 | WARNING | 0.0.0.2 | 172.17.0.2 | dbservice2 | [memory_anomalies] trigger a high memory pro...
# 4  2021-07-06 13:50:30,546 | WARNING | 0.0.0.2 | 172.17.0.2 | dbservice2 | [memory_anomalies] trigger a high memory pro...
#
#    target_root_idx target_root_name  pred_root_idx pred_root_name  \
# 0                6      webservice1              5  redisservice2
# 1                0       dbservice1              5  redisservice2
# 2                0       dbservice1              5  redisservice2
# 3                1       dbservice2              5  redisservice2
# 4                1       dbservice2              5  redisservice2
#
#    target_type_idx    target_type_name  pred_type_idx      pred_type_name  \
# 0                2  [memory_anomalies]              2  [memory_anomalies]
# 1                2  [memory_anomalies]              2  [memory_anomalies]
# 2                2  [memory_anomalies]              2  [memory_anomalies]
# 3                2  [memory_anomalies]              2  [memory_anomalies]
# 4                2  [memory_anomalies]              2  [memory_anomalies]
#
#    root_correct  type_correct  pred_root_confidence  pred_type_confidence  \
# 0         False          True              0.161121              0.918222
# 1         False          True              0.151477              0.914317
# 2         False          True              0.154521              0.915589
# 3         False          True              0.153346              0.914829
# 4         False          True              0.150994              0.913383
#
#   root_top5_indices  \
# 0   [5, 3, 2, 7, 4]
# 1   [5, 2, 3, 7, 4]
# 2   [5, 3, 2, 7, 4]
# 3   [5, 2, 3, 7, 4]
# 4   [5, 2, 3, 7, 4]
#
#                                                          root_top5_names  \
# 0  [redisservice2, logservice2, logservice1, webservice2, redisservice1]
# 1  [redisservice2, logservice1, logservice2, webservice2, redisservice1]
# 2  [redisservice2, logservice2, logservice1, webservice2, redisservice1]
# 3  [redisservice2, logservice1, logservice2, webservice2, redisservice1]
# 4  [redisservice2, logservice1, logservice2, webservice2, redisservice1]
#
#                                                                                             root_top5_scores  \
# 0  [0.16112074255943298, 0.15669412910938263, 0.13755933940410614, 0.12856853008270264, 0.12769247591495514]
# 1      [0.1514773815870285, 0.14762641489505768, 0.14516089856624603, 0.137528657913208, 0.1253747195005417]
# 2  [0.15452079474925995, 0.14935031533241272, 0.14576709270477295, 0.13523922860622406, 0.12493612617254257]
# 3  [0.15334618091583252, 0.14654061198234558, 0.14592914283275604, 0.13687172532081604, 0.12498817592859268]
# 4   [0.15099367499351501, 0.14706088602542877, 0.1444634348154068, 0.13875612616539001, 0.12522992491722107]
#
#   type_ranked_indices  \
# 0        [2, 1, 3, 0]
# 1        [2, 1, 3, 0]
# 2        [2, 1, 3, 0]
# 3        [2, 1, 3, 0]
# 4        [2, 1, 3, 0]
#
#                                                                                                 type_ranked_names  \
# 0  [[memory_anomalies], [file moving program], [normal memory freed label], [access permission denied exception]]
# 1  [[memory_anomalies], [file moving program], [normal memory freed label], [access permission denied exception]]
# 2  [[memory_anomalies], [file moving program], [normal memory freed label], [access permission denied exception]]
# 3  [[memory_anomalies], [file moving program], [normal memory freed label], [access permission denied exception]]
# 4  [[memory_anomalies], [file moving program], [normal memory freed label], [access permission denied exception]]
#
#                                                                        type_ranked_scores
# 0  [0.9182220697402954, 0.061753131449222565, 0.015912305563688278, 0.004112388473004103]
# 1   [0.9143168926239014, 0.06206050515174866, 0.018910346552729607, 0.004712333902716637]
# 2      [0.9155890941619873, 0.06157339736819267, 0.0182394590228796, 0.00459800660610199]
# 3  [0.9148285984992981, 0.06190009042620659, 0.018615391105413437, 0.0046559711918234825]
# 4  [0.9133827686309814, 0.06270890682935715, 0.019128315150737762, 0.0047799949534237385]

# %%
root_report_without_mobservice = classification_report(
    predictions_without_mobservice_df['target_root_name'],
    predictions_without_mobservice_df['pred_root_name'],
    labels=instance_names,
    output_dict=True,
    zero_division=0,
)
type_report_without_mobservice = classification_report(
    predictions_without_mobservice_df['target_type_name'],
    predictions_without_mobservice_df['pred_type_name'],
    labels=failure_type_names,
    output_dict=True,
    zero_division=0,
)

root_report_without_mobservice_df = pd.DataFrame(root_report_without_mobservice).transpose()
type_report_without_mobservice_df = pd.DataFrame(type_report_without_mobservice).transpose()

root_report_df.to_csv(OUTPUT_DIR / 'classification_report_rcl_without_mobservice.csv')
type_report_df.to_csv(OUTPUT_DIR / 'classification_report_fti_without_mobservice.csv')

display(root_report_without_mobservice_df)
display(type_report_without_mobservice_df)
# Out:
#                precision    recall  f1-score     support
# dbservice1      0.000000  0.000000  0.000000   69.000000
# dbservice2      0.000000  0.000000  0.000000   87.000000
# logservice1     0.500000  0.018182  0.035088   55.000000
# logservice2     0.000000  0.000000  0.000000   51.000000
# redisservice1   0.000000  0.000000  0.000000   47.000000
# redisservice2   0.093275  0.895833  0.168959   48.000000
# webservice1     0.000000  0.000000  0.000000   78.000000
# webservice2     0.130435  0.078947  0.098361   76.000000
# accuracy        0.097847  0.097847  0.097847    0.097847
# macro avg       0.090464  0.124120  0.037801  511.000000
# weighted avg    0.081977  0.097847  0.034276  511.000000
#                                       precision    recall  f1-score  \
# [access permission denied exception]   0.000000  0.000000  0.000000
# [file moving program]                  0.000000  0.000000  0.000000
# [memory_anomalies]                     0.872798  1.000000  0.932079
# [normal memory freed label]            0.000000  0.000000  0.000000
# accuracy                               0.872798  0.872798  0.872798
# macro avg                              0.218200  0.250000  0.233020
# weighted avg                           0.761777  0.872798  0.813517
#
#                                          support
# [access permission denied exception]   15.000000
# [file moving program]                  37.000000
# [memory_anomalies]                    446.000000
# [normal memory freed label]            13.000000
# accuracy                                0.872798
# macro avg                             511.000000
# weighted avg                          511.000000

# %%
root_cm_without_mobservice = confusion_matrix(
    predictions_without_mobservice_df['target_root_name'],
    predictions_without_mobservice_df['pred_root_name'],
    labels=instance_names,
)
type_cm_without_mobservice = confusion_matrix(
    predictions_without_mobservice_df['target_type_name'],
    predictions_without_mobservice_df['pred_type_name'],
    labels=failure_type_names,
)

pd.DataFrame(root_cm_without_mobservice, index=instance_names, columns=instance_names).to_csv(OUTPUT_DIR / 'confusion_matrix_rcl_without_mobservice.csv')
pd.DataFrame(type_cm_without_mobservice, index=failure_type_names, columns=failure_type_names).to_csv(OUTPUT_DIR / 'confusion_matrix_fti_without_mobservice.csv')

fig_root = plot_confusion_matrix(root_cm_without_mobservice, instance_names, 'RCL Confusion Matrix')
fig_type = plot_confusion_matrix(type_cm_without_mobservice, failure_type_names, 'FTI Confusion Matrix', rotate_x=25)

fig_root.savefig(OUTPUT_DIR / 'confusion_matrix_rcl_without_mobservice.png', bbox_inches='tight')
fig_type.savefig(OUTPUT_DIR / 'confusion_matrix_fti_without_mobservice.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Only metrics evaluation

# %%
only_metric_args = Namespace(
    dataset=DATASET,
    labels_file=LABELS_FILE,
    embedding_dim=128,
    graph_hidden=128,
    graph_out=32,
    num_heads=16,
    num_layers=2,
    attn_drop=0.0,
    linear_hidden=[64],
    reconstruct=True,
    aug_percent=0.2,
    N_I = len(instance_names),
    N_T = len(failure_type_names),
    modalities = "metric"
)

only_metrics_predictions_df = build_predictions_df(
    args=only_metric_args,
    CHECKPOINT_PATH=ONLY_METRICS_CHECKPOINT_PATH,
    test_loader=test_loader,
    test_meta=test_meta,
    instance_names=instance_names,
    failure_type_names=failure_type_names,
    instance_id_to_name=instance_id_to_name,
    failure_type_id_to_name=failure_type_id_to_name,
    MainModel=MainModel,
    DEVICE=DEVICE,
)

only_metrics_predictions_df.head()
# Out:
# From Main Model:  {'metric'}
#    sample_position  data_index    datetime     service  \
# 0                0        2431  2021-07-05  mobservice
# 1                1        2432  2021-07-05  mobservice
# 2                2        2433  2021-07-05  mobservice
# 3                3        2434  2021-07-05  mobservice
# 4                4        2435  2021-07-05  mobservice
#
#                                                                                                                    message  \
# 0  2021-07-05 21:42:01,380 | WARNING | 0.0.0.1 | 172.17.0.5 | mobservice1 | 86ec9abb15b5ff80 | wait for 11 seconds for ...
# 1  2021-07-05 21:42:32,616 | WARNING | 0.0.0.4 | 172.17.0.2 | mobservice2 | b13e6cdef1c77e0f | wait for 11 seconds for ...
# 2  2021-07-05 21:45:00,329 | WARNING | 0.0.0.1 | 172.17.0.5 | mobservice1 | 5930623f2070d5ba | wait for 11 seconds for ...
# 3  2021-07-05 21:49:00,904 | WARNING | 0.0.0.1 | 172.17.0.5 | mobservice1 | 2375b8b74da928f8 | wait for 11 seconds for ...
# 4  2021-07-05 21:50:37,731 | WARNING | 0.0.0.4 | 172.17.0.2 | mobservice2 | 286d315a73923371 | wait for 11 seconds for ...
#
#    target_root_idx target_root_name  pred_root_idx pred_root_name  \
# 0                4      mobservice1              4    mobservice1
# 1                5      mobservice2              4    mobservice1
# 2                4      mobservice1              4    mobservice1
# 3                4      mobservice1              4    mobservice1
# 4                5      mobservice2              4    mobservice1
#
#    target_type_idx target_type_name  pred_type_idx   pred_type_name  \
# 0                2  [login failure]              2  [login failure]
# 1                2  [login failure]              2  [login failure]
# 2                2  [login failure]              2  [login failure]
# 3                2  [login failure]              2  [login failure]
# 4                2  [login failure]              2  [login failure]
#
#    root_correct  type_correct  pred_root_confidence  pred_type_confidence  \
# 0          True          True              0.626888              1.000000
# 1         False          True              0.657098              1.000000
# 2          True          True              0.615592              1.000000
# 3          True          True              0.869796              0.999999
# 4         False          True              0.855779              0.999999
#
#   root_top5_indices  \
# 0   [4, 5, 1, 2, 6]
# 1   [4, 5, 1, 2, 6]
# 2   [4, 5, 1, 2, 6]
# 3   [4, 5, 1, 2, 6]
# 4   [4, 5, 1, 2, 6]
#
#                                                       root_top5_names  \
# 0  [mobservice1, mobservice2, dbservice2, logservice1, redisservice1]
# 1  [mobservice1, mobservice2, dbservice2, logservice1, redisservice1]
# 2  [mobservice1, mobservice2, dbservice2, logservice1, redisservice1]
# 3  [mobservice1, mobservice2, dbservice2, logservice1, redisservice1]
# 4  [mobservice1, mobservice2, dbservice2, logservice1, redisservice1]
#
#                                                                                                    root_top5_scores  \
# 0  [0.6268879175186157, 0.3730875253677368, 1.4435851880989503e-05, 2.6453515147295548e-06, 2.4469472919008695e-06]
# 1   [0.6570982336997986, 0.3428809642791748, 1.2684556168096606e-05, 2.121701072610449e-06, 1.9517563032422913e-06]
# 2   [0.6155922412872314, 0.38438573479652405, 1.3063410733593628e-05, 2.276406576129375e-06, 2.169834942833404e-06]
# 3  [0.8697956204414368, 0.13018688559532166, 1.0174104318139143e-05, 2.6801910735230194e-06, 2.192826059399522e-06]
# 4       [0.8557794094085693, 0.14420185983181, 1.133498881245032e-05, 2.641549826876144e-06, 2.166181957363733e-06]
#
#   type_ranked_indices  \
# 0     [2, 3, 4, 0, 1]
# 1     [2, 3, 4, 0, 1]
# 2     [2, 3, 4, 0, 1]
# 3     [2, 3, 4, 0, 1]
# 4     [2, 3, 4, 0, 1]
#
#                                                                                                          type_ranked_names  \
# 0  [[login failure], [memory_anomalies], [normal memory freed label], [access permission denied exception], [file movin...
# 1  [[login failure], [memory_anomalies], [normal memory freed label], [access permission denied exception], [file movin...
# 2  [[login failure], [memory_anomalies], [normal memory freed label], [access permission denied exception], [file movin...
# 3  [[login failure], [memory_anomalies], [normal memory freed label], [access permission denied exception], [file movin...
# 4  [[login failure], [memory_anomalies], [normal memory freed label], [access permission denied exception], [file movin...
#
#                                                                                                    type_ranked_scores
# 0   [0.9999995231628418, 4.6194207925509545e-07, 2.023543999030153e-08, 5.640546623525422e-13, 1.064484871776683e-13]
# 1   [0.9999996423721313, 3.253564955230104e-07, 1.4143977544733843e-08, 3.425526735097856e-13, 6.100185596458543e-14]
# 2   [0.9999996423721313, 3.805014614499669e-07, 1.6851679163210065e-08, 4.2890566315581524e-13, 7.94351157117415e-14]
# 3  [0.9999991655349731, 8.509784947818844e-07, 3.6297521432970825e-08, 6.652628751699363e-13, 1.2019175260093162e-13]
# 4   [0.9999992847442627, 7.407185762531299e-07, 3.168548445842134e-08, 6.012007298245026e-13, 1.0742729812272464e-13]

# %%
only_metrics_root_report = classification_report(
    only_metrics_predictions_df['target_root_name'],
    only_metrics_predictions_df['pred_root_name'],
    labels=instance_names,
    output_dict=True,
    zero_division=0,
)
only_metrics_type_report = classification_report(
    only_metrics_predictions_df['target_type_name'],
    only_metrics_predictions_df['pred_type_name'],
    labels=failure_type_names,
    output_dict=True,
    zero_division=0,
)

only_metrics_root_report_df = pd.DataFrame(only_metrics_root_report).transpose()
only_metrics_type_report_df = pd.DataFrame(only_metrics_type_report).transpose()

only_metrics_root_report_df.to_csv(OUTPUT_DIR / 'only_metrics_classification_report_rcl.csv')
only_metrics_type_report_df.to_csv(OUTPUT_DIR / 'only_metrics_classification_report_fti.csv')

display(only_metrics_root_report_df)
display(only_metrics_type_report_df)
# Out:
#                precision    recall  f1-score       support
# dbservice1      0.000000  0.000000  0.000000     69.000000
# dbservice2      0.000000  0.000000  0.000000     87.000000
# logservice1     0.000000  0.000000  0.000000     55.000000
# logservice2     0.000000  0.000000  0.000000     51.000000
# mobservice1     0.491714  0.380622  0.429094   6626.000000
# mobservice2     0.467206  0.608558  0.528596   6637.000000
# redisservice1   0.000000  0.000000  0.000000     47.000000
# redisservice2   0.000000  0.000000  0.000000     48.000000
# webservice1     0.000000  0.000000  0.000000     78.000000
# webservice2     0.000000  0.000000  0.000000     76.000000
# accuracy        0.476332  0.476332  0.476332      0.476332
# macro avg       0.095892  0.098918  0.095769  13774.000000
# weighted avg    0.461663  0.476332  0.461120  13774.000000
#                                       precision    recall  f1-score  \
# [access permission denied exception]   0.000000  0.000000  0.000000
# [file moving program]                  0.000000  0.000000  0.000000
# [login failure]                        0.954189  1.000000  0.976558
# [memory_anomalies]                     0.000000  0.000000  0.000000
# [normal memory freed label]            0.000000  0.000000  0.000000
# accuracy                               0.954189  0.954189  0.954189
# macro avg                              0.190838  0.200000  0.195312
# weighted avg                           0.910477  0.954189  0.931821
#
#                                            support
# [access permission denied exception]     15.000000
# [file moving program]                    37.000000
# [login failure]                       13143.000000
# [memory_anomalies]                      564.000000
# [normal memory freed label]              15.000000
# accuracy                                  0.954189
# macro avg                             13774.000000
# weighted avg                          13774.000000

# %% [markdown]
# ## Only logs evaluation

# %%
only_logs_args = Namespace(
    dataset=DATASET,
    labels_file=LABELS_FILE,
    embedding_dim=128,
    graph_hidden=128,
    graph_out=32,
    num_heads=16,
    num_layers=2,
    attn_drop=0.0,
    linear_hidden=[64],
    reconstruct=True,
    aug_percent=0.2,
    N_I = len(instance_names),
    N_T = len(failure_type_names),
    modalities = "log"
)

only_logs_predictions_df = build_predictions_df(
    args=only_logs_args,
    CHECKPOINT_PATH=ONLY_LOGS_CHECKPOINT_PATH,
    test_loader=test_loader,
    test_meta=test_meta,
    instance_names=instance_names,
    failure_type_names=failure_type_names,
    instance_id_to_name=instance_id_to_name,
    failure_type_id_to_name=failure_type_id_to_name,
    MainModel=MainModel,
    DEVICE=DEVICE,
)

only_logs_predictions_df.head()
# Out:
# From Main Model:  {'log'}
#    sample_position  data_index    datetime     service  \
# 0                0        2431  2021-07-05  mobservice
# 1                1        2432  2021-07-05  mobservice
# 2                2        2433  2021-07-05  mobservice
# 3                3        2434  2021-07-05  mobservice
# 4                4        2435  2021-07-05  mobservice
#
#                                                                                                                    message  \
# 0  2021-07-05 21:42:01,380 | WARNING | 0.0.0.1 | 172.17.0.5 | mobservice1 | 86ec9abb15b5ff80 | wait for 11 seconds for ...
# 1  2021-07-05 21:42:32,616 | WARNING | 0.0.0.4 | 172.17.0.2 | mobservice2 | b13e6cdef1c77e0f | wait for 11 seconds for ...
# 2  2021-07-05 21:45:00,329 | WARNING | 0.0.0.1 | 172.17.0.5 | mobservice1 | 5930623f2070d5ba | wait for 11 seconds for ...
# 3  2021-07-05 21:49:00,904 | WARNING | 0.0.0.1 | 172.17.0.5 | mobservice1 | 2375b8b74da928f8 | wait for 11 seconds for ...
# 4  2021-07-05 21:50:37,731 | WARNING | 0.0.0.4 | 172.17.0.2 | mobservice2 | 286d315a73923371 | wait for 11 seconds for ...
#
#    target_root_idx target_root_name  pred_root_idx pred_root_name  \
# 0                4      mobservice1              4    mobservice1
# 1                5      mobservice2              4    mobservice1
# 2                4      mobservice1              4    mobservice1
# 3                4      mobservice1              4    mobservice1
# 4                5      mobservice2              4    mobservice1
#
#    target_type_idx target_type_name  pred_type_idx   pred_type_name  \
# 0                2  [login failure]              2  [login failure]
# 1                2  [login failure]              2  [login failure]
# 2                2  [login failure]              2  [login failure]
# 3                2  [login failure]              2  [login failure]
# 4                2  [login failure]              2  [login failure]
#
#    root_correct  type_correct  pred_root_confidence  pred_type_confidence  \
# 0          True          True              0.523550              0.999984
# 1         False          True              0.521077              0.999990
# 2          True          True              0.531915              0.999990
# 3          True          True              0.537597              0.999991
# 4         False          True              0.512227              0.999988
#
#   root_top5_indices  \
# 0   [4, 5, 0, 6, 9]
# 1   [4, 5, 0, 6, 9]
# 2   [4, 5, 0, 6, 9]
# 3   [4, 5, 0, 6, 9]
# 4   [4, 5, 0, 6, 9]
#
#                                                       root_top5_names  \
# 0  [mobservice1, mobservice2, dbservice1, redisservice1, webservice2]
# 1  [mobservice1, mobservice2, dbservice1, redisservice1, webservice2]
# 2  [mobservice1, mobservice2, dbservice1, redisservice1, webservice2]
# 3  [mobservice1, mobservice2, dbservice1, redisservice1, webservice2]
# 4  [mobservice1, mobservice2, dbservice1, redisservice1, webservice2]
#
#                                                                                                    root_top5_scores  \
# 0  [0.5235496163368225, 0.47622236609458923, 6.082044274080545e-05, 4.9768135795602575e-05, 3.3728771086316556e-05]
# 1    [0.5210766792297363, 0.47875383496284485, 4.31762782682199e-05, 3.692175596370362e-05, 2.4732273232075386e-05]
# 2   [0.5319146513938904, 0.4679145812988281, 4.5215470890980214e-05, 3.7285572034306824e-05, 2.511920320102945e-05]
# 3     [0.5375970602035522, 0.4622582495212555, 3.946527431253344e-05, 3.18184174830094e-05, 2.1144132915651426e-05]
# 4    [0.512226939201355, 0.48759734630584717, 4.472351793083362e-05, 3.850477150990628e-05, 2.5382256353623234e-05]
#
#   type_ranked_indices  \
# 0     [2, 4, 3, 1, 0]
# 1     [2, 4, 3, 1, 0]
# 2     [2, 4, 3, 1, 0]
# 3     [2, 4, 3, 1, 0]
# 4     [2, 4, 3, 1, 0]
#
#                                                                                                          type_ranked_names  \
# 0  [[login failure], [normal memory freed label], [memory_anomalies], [file moving program], [access permission denied ...
# 1  [[login failure], [normal memory freed label], [memory_anomalies], [file moving program], [access permission denied ...
# 2  [[login failure], [normal memory freed label], [memory_anomalies], [file moving program], [access permission denied ...
# 3  [[login failure], [normal memory freed label], [memory_anomalies], [file moving program], [access permission denied ...
# 4  [[login failure], [normal memory freed label], [memory_anomalies], [file moving program], [access permission denied ...
#
#                                                                                                     type_ranked_scores
# 0  [0.9999837875366211, 9.371119631396141e-06, 6.4046544139273465e-06, 3.0698919317728723e-07, 2.0898539787594927e-07]
# 1   [0.9999897480010986, 5.920210242038593e-06, 3.960338290198706e-06, 2.2297638224699767e-07, 1.4108857726569113e-07]
# 2   [0.9999896287918091, 6.04814840698964e-06, 3.9931201172294095e-06, 2.1094413682476443e-07, 1.3550277344620554e-07]
# 3    [0.9999914169311523, 5.008890184399206e-06, 3.2773696148069575e-06, 1.504161843968177e-07, 9.985031823589452e-08]
# 4     [0.9999884366989136, 6.613709047087468e-06, 4.52172571385745e-06, 2.216416987721459e-07, 1.4912056656157802e-07]

# %%
only_logs_root_report = classification_report(
    only_logs_predictions_df['target_root_name'],
    only_logs_predictions_df['pred_root_name'],
    labels=instance_names,
    output_dict=True,
    zero_division=0,
)
only_logs_type_report = classification_report(
    only_logs_predictions_df['target_type_name'],
    only_logs_predictions_df['pred_type_name'],
    labels=failure_type_names,
    output_dict=True,
    zero_division=0,
)

only_logs_root_report_df = pd.DataFrame(only_logs_root_report).transpose()
only_logs_type_report_df = pd.DataFrame(only_logs_type_report).transpose()

only_logs_root_report_df.to_csv(OUTPUT_DIR / 'only_logs_classification_report_rcl.csv')
only_logs_type_report_df.to_csv(OUTPUT_DIR / 'only_logs_classification_report_fti.csv')

display(only_logs_root_report_df)
display(only_logs_type_report_df)
# Out:
#                precision    recall  f1-score      support
# dbservice1      0.000000  0.000000  0.000000     69.00000
# dbservice2      0.166667  0.011494  0.021505     87.00000
# logservice1     0.000000  0.000000  0.000000     55.00000
# logservice2     0.000000  0.000000  0.000000     51.00000
# mobservice1     0.492353  0.957139  0.650228   6626.00000
# mobservice2     0.497317  0.041886  0.077265   6637.00000
# redisservice1   0.250000  0.021277  0.039216     47.00000
# redisservice2   0.214286  0.062500  0.096774     48.00000
# webservice1     0.153846  0.358974  0.215385     78.00000
# webservice2     0.096491  0.144737  0.115789     76.00000
# accuracy        0.483810  0.483810  0.483810      0.48381
# macro avg       0.187096  0.159801  0.121616  13774.00000
# weighted avg    0.480535  0.483810  0.352489  13774.00000
#                                       precision    recall  f1-score  \
# [access permission denied exception]   0.000000  0.000000  0.000000
# [file moving program]                  0.101504  0.729730  0.178218
# [login failure]                        0.981187  1.000000  0.990504
# [memory_anomalies]                     0.973451  0.195035  0.324963
# [normal memory freed label]            0.000000  0.000000  0.000000
# accuracy                               0.964135  0.964135  0.964135
# macro avg                              0.411228  0.384953  0.298737
# weighted avg                           0.976370  0.964135  0.958913
#
#                                            support
# [access permission denied exception]     15.000000
# [file moving program]                    37.000000
# [login failure]                       13143.000000
# [memory_anomalies]                      564.000000
# [normal memory freed label]              15.000000
# accuracy                                  0.964135
# macro avg                             13774.000000
# weighted avg                          13774.000000

# %% [markdown]
# ## Only traces evaluation

# %%
only_traces_args = Namespace(
    dataset=DATASET,
    labels_file=LABELS_FILE,
    embedding_dim=128,
    graph_hidden=128,
    graph_out=32,
    num_heads=16,
    num_layers=2,
    attn_drop=0.0,
    linear_hidden=[64],
    reconstruct=True,
    aug_percent=0.2,
    N_I = len(instance_names),
    N_T = len(failure_type_names),
    modalities = "trace"
)

only_traces_predictions_df = build_predictions_df(
    args=only_traces_args,
    CHECKPOINT_PATH=ONLY_TRACES_CHECKPOINT_PATH,
    test_loader=test_loader,
    test_meta=test_meta,
    instance_names=instance_names,
    failure_type_names=failure_type_names,
    instance_id_to_name=instance_id_to_name,
    failure_type_id_to_name=failure_type_id_to_name,
    MainModel=MainModel,
    DEVICE=DEVICE,
)

only_traces_predictions_df.head()
# Out:
# From Main Model:  {'trace'}
#    sample_position  data_index    datetime     service  \
# 0                0        2431  2021-07-05  mobservice
# 1                1        2432  2021-07-05  mobservice
# 2                2        2433  2021-07-05  mobservice
# 3                3        2434  2021-07-05  mobservice
# 4                4        2435  2021-07-05  mobservice
#
#                                                                                                                    message  \
# 0  2021-07-05 21:42:01,380 | WARNING | 0.0.0.1 | 172.17.0.5 | mobservice1 | 86ec9abb15b5ff80 | wait for 11 seconds for ...
# 1  2021-07-05 21:42:32,616 | WARNING | 0.0.0.4 | 172.17.0.2 | mobservice2 | b13e6cdef1c77e0f | wait for 11 seconds for ...
# 2  2021-07-05 21:45:00,329 | WARNING | 0.0.0.1 | 172.17.0.5 | mobservice1 | 5930623f2070d5ba | wait for 11 seconds for ...
# 3  2021-07-05 21:49:00,904 | WARNING | 0.0.0.1 | 172.17.0.5 | mobservice1 | 2375b8b74da928f8 | wait for 11 seconds for ...
# 4  2021-07-05 21:50:37,731 | WARNING | 0.0.0.4 | 172.17.0.2 | mobservice2 | 286d315a73923371 | wait for 11 seconds for ...
#
#    target_root_idx target_root_name  pred_root_idx pred_root_name  \
# 0                4      mobservice1              5    mobservice2
# 1                5      mobservice2              5    mobservice2
# 2                4      mobservice1              5    mobservice2
# 3                4      mobservice1              4    mobservice1
# 4                5      mobservice2              5    mobservice2
#
#    target_type_idx target_type_name  pred_type_idx   pred_type_name  \
# 0                2  [login failure]              2  [login failure]
# 1                2  [login failure]              2  [login failure]
# 2                2  [login failure]              2  [login failure]
# 3                2  [login failure]              2  [login failure]
# 4                2  [login failure]              2  [login failure]
#
#    root_correct  type_correct  pred_root_confidence  pred_type_confidence  \
# 0         False          True              0.999884              0.999830
# 1          True          True              0.998719              0.994101
# 2         False          True              0.996082              0.997745
# 3          True          True              0.329117              0.641125
# 4          True          True              0.995406              0.997016
#
#   root_top5_indices  \
# 0   [5, 6, 4, 3, 0]
# 1   [5, 6, 3, 0, 2]
# 2   [5, 6, 4, 0, 3]
# 3   [4, 0, 1, 6, 9]
# 4   [5, 6, 4, 0, 3]
#
#                                                       root_top5_names  \
# 0  [mobservice2, redisservice1, mobservice1, logservice2, dbservice1]
# 1  [mobservice2, redisservice1, logservice2, dbservice1, logservice1]
# 2  [mobservice2, redisservice1, mobservice1, dbservice1, logservice2]
# 3   [mobservice1, dbservice1, dbservice2, redisservice1, webservice2]
# 4  [mobservice2, redisservice1, mobservice1, dbservice1, logservice2]
#
#                                                                                                     root_top5_scores  \
# 0  [0.9998842477798462, 6.802938150940463e-05, 3.1565625249641016e-05, 8.072739547060337e-06, 5.404646799433976e-06]
# 1    [0.9987187385559082, 0.000971645989920944, 0.00015479612920898944, 9.34911731746979e-05, 4.269305645721033e-05]
# 2   [0.9960824251174927, 0.0015820207772776484, 0.0013488662661984563, 0.0004634111246559769, 0.0002498340036254376]
# 3            [0.329117089509964, 0.23532481491565704, 0.20011909306049347, 0.10745503008365631, 0.10094963014125824]
# 4  [0.9954061508178711, 0.0021662202198058367, 0.0012504254700616002, 0.0006768289022147655, 0.00017606215260457247]
#
#   type_ranked_indices  \
# 0     [2, 3, 4, 0, 1]
# 1     [2, 3, 4, 0, 1]
# 2     [2, 3, 4, 0, 1]
# 3     [2, 3, 4, 0, 1]
# 4     [2, 3, 4, 0, 1]
#
#                                                                                                          type_ranked_names  \
# 0  [[login failure], [memory_anomalies], [normal memory freed label], [access permission denied exception], [file movin...
# 1  [[login failure], [memory_anomalies], [normal memory freed label], [access permission denied exception], [file movin...
# 2  [[login failure], [memory_anomalies], [normal memory freed label], [access permission denied exception], [file movin...
# 3  [[login failure], [memory_anomalies], [normal memory freed label], [access permission denied exception], [file movin...
# 4  [[login failure], [memory_anomalies], [normal memory freed label], [access permission denied exception], [file movin...
#
#                                                                                                     type_ranked_scores
# 0  [0.9998296499252319, 0.0001661178976064548, 2.4577714157203445e-06, 1.5576947589579504e-06, 1.0829933216882637e-07]
# 1      [0.9941012263298035, 0.005769196432083845, 0.0001051956569426693, 2.196275454480201e-05, 2.397037178525352e-06]
# 2    [0.9977450966835022, 0.0019848879892379045, 0.00015665925457142293, 9.973520354833454e-05, 1.349888952972833e-05]
# 3            [0.6411250233650208, 0.23966990411281586, 0.0942639708518982, 0.014952166937291622, 0.009988916106522083]
# 4  [0.9970157146453857, 0.0026366496458649635, 0.00023220691946335137, 0.00010022895003203303, 1.5230963981593959e-05]

# %%
only_traces_root_report = classification_report(
    only_traces_predictions_df['target_root_name'],
    only_traces_predictions_df['pred_root_name'],
    labels=instance_names,
    output_dict=True,
    zero_division=0,
)
only_traces_type_report = classification_report(
    only_traces_predictions_df['target_type_name'],
    only_traces_predictions_df['pred_type_name'],
    labels=failure_type_names,
    output_dict=True,
    zero_division=0,
)

only_traces_root_report_df = pd.DataFrame(only_traces_root_report).transpose()
only_traces_type_report_df = pd.DataFrame(only_traces_type_report).transpose()

only_traces_root_report_df.to_csv(OUTPUT_DIR / 'only_traces_classification_report_rcl.csv')
only_traces_type_report_df.to_csv(OUTPUT_DIR / 'only_traces_classification_report_fti.csv')

display(only_traces_root_report_df)
display(only_traces_type_report_df)
# Out:
#                precision    recall  f1-score       support
# dbservice1      0.000968  0.043478  0.001893     69.000000
# dbservice2      0.000000  0.000000  0.000000     87.000000
# logservice1     0.000000  0.000000  0.000000     55.000000
# logservice2     0.000000  0.000000  0.000000     51.000000
# mobservice1     0.980192  0.246453  0.393874   6626.000000
# mobservice2     0.733683  0.928130  0.819530   6637.000000
# redisservice1   0.039216  0.255319  0.067989     47.000000
# redisservice2   0.000000  0.000000  0.000000     48.000000
# webservice1     0.000000  0.000000  0.000000     78.000000
# webservice2     0.000000  0.000000  0.000000     76.000000
# accuracy        0.566865  0.566865  0.566865      0.566865
# macro avg       0.175406  0.147338  0.128329  13774.000000
# weighted avg    0.825186  0.566865  0.584605  13774.000000
#                                       precision    recall  f1-score  \
# [access permission denied exception]   0.000000  0.000000  0.000000
# [file moving program]                  0.000000  0.000000  0.000000
# [login failure]                        0.964138  0.744579  0.840252
# [memory_anomalies]                     0.065673  0.421986  0.113658
# [normal memory freed label]            0.000000  0.000000  0.000000
# accuracy                               0.727748  0.727748  0.727748
# macro avg                              0.205962  0.233313  0.190782
# weighted avg                           0.922659  0.727748  0.806414
#
#                                            support
# [access permission denied exception]     15.000000
# [file moving program]                    37.000000
# [login failure]                       13143.000000
# [memory_anomalies]                      564.000000
# [normal memory freed label]              15.000000
# accuracy                                  0.727748
# macro avg                             13774.000000
# weighted avg                          13774.000000

# %% [markdown]
# # Loss experiments
# 1. Weighted cross-entory loss

# %%
WEIGHTED_CE_CHECKPOINT_PATH = 'logs/gaia/corrected_index_data_trained_model_gaia_weighted_ce.pt'
weighted_ce_args = Namespace(
    dataset=DATASET,
    labels_file=LABELS_FILE,
    embedding_dim=128,
    graph_hidden=128,
    graph_out=32,
    num_heads=16,
    num_layers=2,
    attn_drop=0.0,
    linear_hidden=[64],
    reconstruct=True,
    aug_percent=0.2,
    N_I = len(instance_names),
    N_T = len(failure_type_names),
    root_loss = 'weighted_ce',
    type_loss = 'weighted_ce'
)

weighted_ce_df = build_predictions_df(
    args=weighted_ce_args,
    CHECKPOINT_PATH=WEIGHTED_CE_CHECKPOINT_PATH,
    test_loader=test_loader,
    test_meta=test_meta,
    instance_names=instance_names,
    failure_type_names=failure_type_names,
    instance_id_to_name=instance_id_to_name,
    failure_type_id_to_name=failure_type_id_to_name,
    MainModel=MainModel,
    DEVICE=DEVICE,
)

weighted_ce_df.head()
# Out:
# From Main Model:  {'metric', 'trace', 'log'}
# Root loss:  weighted_ce fault type loss:  weighted_ce
#    sample_position  data_index    datetime     service  \
# 0                0        1980  2021-07-05  webservice
# 1                1        2203  2021-07-05  mobservice
# 2                2        2204  2021-07-05  mobservice
# 3                3        2205  2021-07-05  mobservice
# 4                4        2206  2021-07-05  mobservice
#
#                                                                                                                    message  \
# 0  2021-07-05 22:09:15,582 | WARNING | 0.0.0.1 | 172.17.0.3 | webservice1 | [memory_anomalies] trigger a high memory pr...
# 1  2021-07-05 21:42:32,616 | WARNING | 0.0.0.4 | 172.17.0.2 | mobservice2 | b13e6cdef1c77e0f | wait for 11 seconds for ...
# 2  2021-07-05 21:50:37,731 | WARNING | 0.0.0.4 | 172.17.0.2 | mobservice2 | 286d315a73923371 | wait for 11 seconds for ...
# 3  2021-07-05 21:56:26,911 | WARNING | 0.0.0.4 | 172.17.0.2 | mobservice2 | b1eeed119a0ffca5 | wait for 11 seconds for ...
# 4  2021-07-05 22:06:04,641 | WARNING | 0.0.0.4 | 172.17.0.2 | mobservice2 | 1a06c7b08f348618 | wait for 11 seconds for ...
#
#    target_root_idx target_root_name  pred_root_idx pred_root_name  \
# 0                8      webservice1              0     dbservice1
# 1                5      mobservice2              5    mobservice2
# 2                5      mobservice2              5    mobservice2
# 3                5      mobservice2              5    mobservice2
# 4                5      mobservice2              5    mobservice2
#
#    target_type_idx    target_type_name  pred_type_idx      pred_type_name  \
# 0                3  [memory_anomalies]              3  [memory_anomalies]
# 1                2     [login failure]              2     [login failure]
# 2                2     [login failure]              2     [login failure]
# 3                2     [login failure]              2     [login failure]
# 4                2     [login failure]              2     [login failure]
#
#    root_correct  type_correct  pred_root_confidence  pred_type_confidence  \
# 0         False          True              0.629640              0.994745
# 1          True          True              0.996607              0.999971
# 2          True          True              0.835182              0.999999
# 3          True          True              0.995630              0.999958
# 4          True          True              0.995764              0.999970
#
#   root_top5_indices  \
# 0   [0, 9, 6, 5, 1]
# 1   [5, 4, 0, 9, 1]
# 2   [5, 4, 9, 0, 1]
# 3   [5, 4, 0, 9, 1]
# 4   [5, 4, 0, 9, 1]
#
#                                                      root_top5_names  \
# 0  [dbservice1, webservice2, redisservice1, mobservice2, dbservice2]
# 1    [mobservice2, mobservice1, dbservice1, webservice2, dbservice2]
# 2    [mobservice2, mobservice1, webservice2, dbservice1, dbservice2]
# 3    [mobservice2, mobservice1, dbservice1, webservice2, dbservice2]
# 4    [mobservice2, mobservice1, dbservice1, webservice2, dbservice2]
#
#                                                                                                     root_top5_scores  \
# 0           [0.6296396851539612, 0.2798307240009308, 0.06387044489383698, 0.012805217877030373, 0.01068263128399849]
# 1  [0.9966073036193848, 0.0029567552264779806, 0.00034324583248235285, 8.660341700306162e-05, 5.655492259393213e-06]
# 2     [0.8351820111274719, 0.16473665833473206, 4.568430449580774e-05, 2.425363527436275e-05, 9.125662472797558e-06]
# 3      [0.9956303834915161, 0.0039306222461164, 0.00033714549499563873, 9.300681995227933e-05, 8.46473722049268e-06]
# 4   [0.9957642555236816, 0.003799573751166463, 0.00033082099980674684, 9.957194561138749e-05, 5.360237992135808e-06]
#
#   type_ranked_indices  \
# 0     [3, 4, 1, 2, 0]
# 1     [2, 3, 4, 1, 0]
# 2     [2, 3, 1, 4, 0]
# 3     [2, 3, 4, 1, 0]
# 4     [2, 3, 4, 1, 0]
#
#                                                                                                          type_ranked_names  \
# 0  [[memory_anomalies], [normal memory freed label], [file moving program], [login failure], [access permission denied ...
# 1  [[login failure], [memory_anomalies], [normal memory freed label], [file moving program], [access permission denied ...
# 2  [[login failure], [memory_anomalies], [file moving program], [normal memory freed label], [access permission denied ...
# 3  [[login failure], [memory_anomalies], [normal memory freed label], [file moving program], [access permission denied ...
# 4  [[login failure], [memory_anomalies], [normal memory freed label], [file moving program], [access permission denied ...
#
#                                                                                                   type_ranked_scores
# 0    [0.9947448968887329, 0.003418838605284691, 0.001548354048281908, 0.00026749010430648923, 2.040954313997645e-05]
# 1  [0.9999711513519287, 2.6291423637303524e-05, 2.456333277223166e-06, 8.305389798124452e-08, 6.943371744227989e-08]
# 2    [0.9999994039535522, 5.220858838583808e-07, 3.75229554094858e-08, 2.523817954624974e-08, 5.857389573371563e-10]
# 3  [0.9999581575393677, 3.645657125161961e-05, 5.161192348168697e-06, 1.0558704843788291e-07, 9.749367535505371e-08]
# 4  [0.9999704360961914, 2.6760963010019623e-05, 2.642668277985649e-06, 9.541422940628763e-08, 6.623018578011397e-08]

# %%
weighted_ce_root_report = classification_report(
    weighted_ce_df['target_root_name'],
    weighted_ce_df['pred_root_name'],
    labels=instance_names,
    output_dict=True,
    zero_division=0,
)
weighted_ce_type_report = classification_report(
    weighted_ce_df['target_type_name'],
    weighted_ce_df['pred_type_name'],
    labels=failure_type_names,
    output_dict=True,
    zero_division=0,
)

weighted_ce_root_report_df = pd.DataFrame(weighted_ce_root_report).transpose()
weighted_ce_type_report_df = pd.DataFrame(weighted_ce_type_report).transpose()

weighted_ce_root_report_df.to_csv(OUTPUT_DIR / 'weighted_ce_classification_report_rcl.csv')
weighted_ce_type_report_df.to_csv(OUTPUT_DIR / 'weighted_ce_classification_report_fti.csv')

display(weighted_ce_root_report_df)
display(weighted_ce_type_report_df)
# Out:
#                precision    recall  f1-score       support
# dbservice1      0.094937  0.217391  0.132159     69.000000
# dbservice2      0.140845  0.114943  0.126582     87.000000
# logservice1     0.000000  0.000000  0.000000     55.000000
# logservice2     0.179487  0.137255  0.155556     51.000000
# mobservice1     0.895317  0.147148  0.252754   6626.000000
# mobservice2     0.534037  0.968058  0.688344   6637.000000
# redisservice1   0.089172  0.297872  0.137255     47.000000
# redisservice2   0.120000  0.062500  0.082192     48.000000
# webservice1     0.072917  0.089744  0.080460     78.000000
# webservice2     0.074766  0.105263  0.087432     76.000000
# accuracy        0.541891  0.541891  0.541891      0.541891
# macro avg       0.220148  0.214017  0.174273  13774.000000
# weighted avg    0.691597  0.541891  0.456996  13774.000000
#                                       precision    recall  f1-score  \
# [access permission denied exception]   0.000000  0.000000  0.000000
# [file moving program]                  0.058511  0.297297  0.097778
# [login failure]                        0.994212  0.993228  0.993720
# [memory_anomalies]                     0.761682  0.578014  0.657258
# [normal memory freed label]            0.000000  0.000000  0.000000
# accuracy                               0.972194  0.972194  0.972194
# macro avg                              0.362881  0.373708  0.349751
# weighted avg                           0.980012  0.972194  0.975372
#
#                                            support
# [access permission denied exception]     15.000000
# [file moving program]                    37.000000
# [login failure]                       13143.000000
# [memory_anomalies]                      564.000000
# [normal memory freed label]              15.000000
# accuracy                                  0.972194
# macro avg                             13774.000000
# weighted avg                          13774.000000

# %%
weighted_ce_root_cm = confusion_matrix(
    weighted_ce_df['target_root_name'],
    weighted_ce_df['pred_root_name'],
    labels=instance_names,
)
weighted_ce_type_cm = confusion_matrix(
    weighted_ce_df['target_type_name'],
    weighted_ce_df['pred_type_name'],
    labels=failure_type_names,
)

pd.DataFrame(weighted_ce_root_cm, index=instance_names, columns=instance_names).to_csv(OUTPUT_DIR / 'weighted_ce_confusion_matrix_rcl.csv')
pd.DataFrame(weighted_ce_type_cm, index=failure_type_names, columns=failure_type_names).to_csv(OUTPUT_DIR / 'weighted_ce_confusion_matrix_fti.csv')

fig_root = plot_confusion_matrix(weighted_ce_root_cm, instance_names, 'RCL Confusion Matrix')
fig_type = plot_confusion_matrix(weighted_ce_type_cm, failure_type_names, 'FTI Confusion Matrix', rotate_x=25)

fig_root.savefig(OUTPUT_DIR / 'weighted_ce_confusion_matrix_rcl.png', bbox_inches='tight')
fig_type.savefig(OUTPUT_DIR / 'weighted_ce_confusion_matrix_fti.png', bbox_inches='tight')
plt.show()

# %%
FOCAL_CHECKPOINT_PATH = 'logs/gaia/corrected_index_data_trained_model_gaia_focal.pt'
focal_args = Namespace(
    dataset=DATASET,
    labels_file=LABELS_FILE,
    embedding_dim=128,
    graph_hidden=128,
    graph_out=32,
    num_heads=16,
    num_layers=2,
    attn_drop=0.0,
    linear_hidden=[64],
    reconstruct=True,
    aug_percent=0.2,
    N_I = len(instance_names),
    N_T = len(failure_type_names),
    root_loss = 'focal',
    type_loss = 'focal',
    focal_gamma = 0.5
)

focal_df = build_predictions_df(
    args=focal_args,
    CHECKPOINT_PATH=FOCAL_CHECKPOINT_PATH,
    test_loader=test_loader,
    test_meta=test_meta,
    instance_names=instance_names,
    failure_type_names=failure_type_names,
    instance_id_to_name=instance_id_to_name,
    failure_type_id_to_name=failure_type_id_to_name,
    MainModel=MainModel,
    DEVICE=DEVICE,
)

focal_df.head()
# Out:
# From Main Model:  {'metric', 'trace', 'log'}
# Root loss:  focal fault type loss:  focal
# Focal gamma:  0.5
#    sample_position  data_index    datetime     service  \
# 0                0        1980  2021-07-05  webservice
# 1                1        2203  2021-07-05  mobservice
# 2                2        2204  2021-07-05  mobservice
# 3                3        2205  2021-07-05  mobservice
# 4                4        2206  2021-07-05  mobservice
#
#                                                                                                                    message  \
# 0  2021-07-05 22:09:15,582 | WARNING | 0.0.0.1 | 172.17.0.3 | webservice1 | [memory_anomalies] trigger a high memory pr...
# 1  2021-07-05 21:42:32,616 | WARNING | 0.0.0.4 | 172.17.0.2 | mobservice2 | b13e6cdef1c77e0f | wait for 11 seconds for ...
# 2  2021-07-05 21:50:37,731 | WARNING | 0.0.0.4 | 172.17.0.2 | mobservice2 | 286d315a73923371 | wait for 11 seconds for ...
# 3  2021-07-05 21:56:26,911 | WARNING | 0.0.0.4 | 172.17.0.2 | mobservice2 | b1eeed119a0ffca5 | wait for 11 seconds for ...
# 4  2021-07-05 22:06:04,641 | WARNING | 0.0.0.4 | 172.17.0.2 | mobservice2 | 1a06c7b08f348618 | wait for 11 seconds for ...
#
#    target_root_idx target_root_name  pred_root_idx pred_root_name  \
# 0                8      webservice1              6  redisservice1
# 1                5      mobservice2              5    mobservice2
# 2                5      mobservice2              5    mobservice2
# 3                5      mobservice2              5    mobservice2
# 4                5      mobservice2              5    mobservice2
#
#    target_type_idx    target_type_name  pred_type_idx      pred_type_name  \
# 0                3  [memory_anomalies]              3  [memory_anomalies]
# 1                2     [login failure]              2     [login failure]
# 2                2     [login failure]              2     [login failure]
# 3                2     [login failure]              2     [login failure]
# 4                2     [login failure]              2     [login failure]
#
#    root_correct  type_correct  pred_root_confidence  pred_type_confidence  \
# 0         False          True              0.290159              0.999916
# 1          True          True              0.999952              0.999904
# 2          True          True              0.761565              0.999465
# 3          True          True              0.999855              0.999930
# 4          True          True              0.999959              0.999922
#
#   root_top5_indices  \
# 0   [6, 7, 2, 1, 3]
# 1   [5, 4, 3, 0, 9]
# 2   [5, 4, 0, 1, 9]
# 3   [5, 4, 0, 3, 9]
# 4   [5, 4, 3, 0, 9]
#
#                                                         root_top5_names  \
# 0  [redisservice1, redisservice2, logservice1, dbservice2, logservice2]
# 1      [mobservice2, mobservice1, logservice2, dbservice1, webservice2]
# 2       [mobservice2, mobservice1, dbservice1, dbservice2, webservice2]
# 3      [mobservice2, mobservice1, dbservice1, logservice2, webservice2]
# 4      [mobservice2, mobservice1, logservice2, dbservice1, webservice2]
#
#                                                                                                      root_top5_scores  \
# 0            [0.2901589572429657, 0.27102118730545044, 0.16283433139324188, 0.13314984738826752, 0.12153705209493637]
# 1  [0.9999524354934692, 4.5619071897817776e-05, 7.057227549012168e-07, 4.620322613391181e-07, 4.4863006110062997e-07]
# 2      [0.7615646719932556, 0.23794524371623993, 0.00011586675827857107, 8.54172685649246e-05, 6.761026452295482e-05]
# 3  [0.9998551607131958, 0.00014160345017444342, 1.3917043588662636e-06, 7.251222200466145e-07, 4.022337520837027e-07]
# 4   [0.9999593496322632, 3.937000656151213e-05, 4.686906436290883e-07, 3.5791561003861716e-07, 2.427776735203224e-07]
#
#   type_ranked_indices  \
# 0     [3, 4, 1, 0, 2]
# 1     [2, 3, 0, 4, 1]
# 2     [2, 3, 4, 0, 1]
# 3     [2, 3, 0, 4, 1]
# 4     [2, 3, 0, 4, 1]
#
#                                                                                                          type_ranked_names  \
# 0  [[memory_anomalies], [normal memory freed label], [file moving program], [access permission denied exception], [logi...
# 1  [[login failure], [memory_anomalies], [access permission denied exception], [normal memory freed label], [file movin...
# 2  [[login failure], [memory_anomalies], [normal memory freed label], [access permission denied exception], [file movin...
# 3  [[login failure], [memory_anomalies], [access permission denied exception], [normal memory freed label], [file movin...
# 4  [[login failure], [memory_anomalies], [access permission denied exception], [normal memory freed label], [file movin...
#
#                                                                                                     type_ranked_scores
# 0     [0.9999158382415771, 7.067328988341615e-05, 7.916303729871288e-06, 3.2264224500977434e-06, 2.41675047618628e-06]
# 1  [0.9999042749404907, 4.1475301259197295e-05, 2.2875365175423212e-05, 1.878101465990767e-05, 1.2616578715096693e-05]
# 2   [0.9994654059410095, 0.00017227102944161743, 0.0001435271551599726, 0.00012807185703422874, 9.073440742213279e-05]
# 3  [0.9999297857284546, 3.0155015338095836e-05, 1.6892377971089445e-05, 1.3994620530866086e-05, 9.123197742155753e-06]
# 4  [0.9999223947525024, 3.396903048269451e-05, 1.8245225874125026e-05, 1.5024266758700833e-05, 1.0316666703147348e-05]

# %%
focal_root_report = classification_report(
    focal_df['target_root_name'],
    focal_df['pred_root_name'],
    labels=instance_names,
    output_dict=True,
    zero_division=0,
)
focal_type_report = classification_report(
    focal_df['target_type_name'],
    focal_df['pred_type_name'],
    labels=failure_type_names,
    output_dict=True,
    zero_division=0,
)

focal_root_report_df = pd.DataFrame(focal_root_report).transpose()
focal_type_report_df = pd.DataFrame(focal_type_report).transpose()

focal_root_report_df.to_csv(OUTPUT_DIR / 'focal_classification_report_rcl.csv')
focal_type_report_df.to_csv(OUTPUT_DIR / 'focal_classification_report_fti.csv')

display(focal_root_report_df)
display(focal_type_report_df)
# Out:
#                precision    recall  f1-score       support
# dbservice1      0.058824  0.043478  0.050000     69.000000
# dbservice2      0.100000  0.034483  0.051282     87.000000
# logservice1     0.078125  0.090909  0.084034     55.000000
# logservice2     0.000000  0.000000  0.000000     51.000000
# mobservice1     0.909891  0.857984  0.883175   6626.000000
# mobservice2     0.859087  0.913063  0.885253   6637.000000
# redisservice1   0.071429  0.063830  0.067416     47.000000
# redisservice2   0.059322  0.145833  0.084337     48.000000
# webservice1     0.133333  0.051282  0.074074     78.000000
# webservice2     0.134615  0.184211  0.155556     76.000000
# accuracy        0.855525  0.855525  0.855525      0.855525
# macro avg       0.240463  0.238507  0.233513  13774.000000
# weighted avg    0.854842  0.855525  0.854123  13774.000000
#                                       precision    recall  f1-score  \
# [access permission denied exception]   0.000000  0.000000  0.000000
# [file moving program]                  0.145299  0.459459  0.220779
# [login failure]                        0.999314  0.998098  0.998706
# [memory_anomalies]                     0.933586  0.872340  0.901925
# [normal memory freed label]            0.333333  0.066667  0.111111
# accuracy                               0.989400  0.989400  0.989400
# macro avg                              0.482307  0.479313  0.446504
# weighted avg                           0.992515  0.989400  0.990599
#
#                                          support
# [access permission denied exception]     15.0000
# [file moving program]                    37.0000
# [login failure]                       13143.0000
# [memory_anomalies]                      564.0000
# [normal memory freed label]              15.0000
# accuracy                                  0.9894
# macro avg                             13774.0000
# weighted avg                          13774.0000

# %%
focal_root_cm = confusion_matrix(
    focal_df['target_root_name'],
    focal_df['pred_root_name'],
    labels=instance_names,
)
focal_type_cm = confusion_matrix(
    focal_df['target_type_name'],
    focal_df['pred_type_name'],
    labels=failure_type_names,
)

pd.DataFrame(focal_root_cm, index=instance_names, columns=instance_names).to_csv(OUTPUT_DIR / 'focal_confusion_matrix_rcl.csv')
pd.DataFrame(focal_type_cm, index=failure_type_names, columns=failure_type_names).to_csv(OUTPUT_DIR / 'focal_confusion_matrix_fti.csv')

fig_root = plot_confusion_matrix(focal_root_cm, instance_names, 'RCL Confusion Matrix')
fig_type = plot_confusion_matrix(focal_type_cm, failure_type_names, 'FTI Confusion Matrix', rotate_x=25)

fig_root.savefig(OUTPUT_DIR / 'focal_confusion_matrix_rcl.png', bbox_inches='tight')
fig_type.savefig(OUTPUT_DIR / 'focal_confusion_matrix_fti.png', bbox_inches='tight')
plt.show()

# %%
FOCAL_CHECKPOINT_PATH_025 = 'logs/gaia/TransTVDiag-metric-trace-log-root_focal_type_focal-focal_gamma_0.25.pt'
focal_args = Namespace(
    dataset=DATASET,
    labels_file=LABELS_FILE,
    embedding_dim=128,
    graph_hidden=128,
    graph_out=32,
    num_heads=16,
    num_layers=2,
    attn_drop=0.0,
    linear_hidden=[64],
    reconstruct=True,
    aug_percent=0.2,
    N_I = len(instance_names),
    N_T = len(failure_type_names),
    root_loss = 'focal',
    type_loss = 'focal',
    focal_gamma = 0.25
)

focal_025_df = build_predictions_df(
    args=focal_args,
    CHECKPOINT_PATH=FOCAL_CHECKPOINT_PATH_025,
    test_loader=test_loader,
    test_meta=test_meta,
    instance_names=instance_names,
    failure_type_names=failure_type_names,
    instance_id_to_name=instance_id_to_name,
    failure_type_id_to_name=failure_type_id_to_name,
    MainModel=MainModel,
    DEVICE=DEVICE,
)

focal_025_df.head()
# Out:
# From Main Model:  {'metric', 'log', 'trace'}
# Root loss:  focal fault type loss:  focal
# Focal gamma:  0.25
#    sample_position  data_index    datetime     service  \
# 0                0        2431  2021-07-05  mobservice
# 1                1        2432  2021-07-05  mobservice
# 2                2        2433  2021-07-05  mobservice
# 3                3        2434  2021-07-05  mobservice
# 4                4        2435  2021-07-05  mobservice
#
#                                                                                                                    message  \
# 0  2021-07-05 21:42:01,380 | WARNING | 0.0.0.1 | 172.17.0.5 | mobservice1 | 86ec9abb15b5ff80 | wait for 11 seconds for ...
# 1  2021-07-05 21:42:32,616 | WARNING | 0.0.0.4 | 172.17.0.2 | mobservice2 | b13e6cdef1c77e0f | wait for 11 seconds for ...
# 2  2021-07-05 21:45:00,329 | WARNING | 0.0.0.1 | 172.17.0.5 | mobservice1 | 5930623f2070d5ba | wait for 11 seconds for ...
# 3  2021-07-05 21:49:00,904 | WARNING | 0.0.0.1 | 172.17.0.5 | mobservice1 | 2375b8b74da928f8 | wait for 11 seconds for ...
# 4  2021-07-05 21:50:37,731 | WARNING | 0.0.0.4 | 172.17.0.2 | mobservice2 | 286d315a73923371 | wait for 11 seconds for ...
#
#    target_root_idx target_root_name  pred_root_idx pred_root_name  \
# 0                4      mobservice1              4    mobservice1
# 1                5      mobservice2              5    mobservice2
# 2                4      mobservice1              4    mobservice1
# 3                4      mobservice1              4    mobservice1
# 4                5      mobservice2              5    mobservice2
#
#    target_type_idx target_type_name  pred_type_idx   pred_type_name  \
# 0                2  [login failure]              2  [login failure]
# 1                2  [login failure]              2  [login failure]
# 2                2  [login failure]              2  [login failure]
# 3                2  [login failure]              2  [login failure]
# 4                2  [login failure]              2  [login failure]
#
#    root_correct  type_correct  pred_root_confidence  pred_type_confidence  \
# 0          True          True              0.950952              0.982648
# 1          True          True              0.947657              0.960995
# 2          True          True              0.999603              0.999458
# 3          True          True              0.998802              0.998470
# 4          True          True              0.576850              0.983035
#
#   root_top5_indices  \
# 0   [4, 5, 8, 3, 2]
# 1   [5, 4, 9, 0, 6]
# 2   [4, 5, 8, 7, 3]
# 3   [4, 5, 7, 8, 3]
# 4   [5, 4, 2, 1, 8]
#
#                                                        root_top5_names  \
# 0    [mobservice1, mobservice2, webservice1, logservice2, logservice1]
# 1   [mobservice2, mobservice1, webservice2, dbservice1, redisservice1]
# 2  [mobservice1, mobservice2, webservice1, redisservice2, logservice2]
# 3  [mobservice1, mobservice2, redisservice2, webservice1, logservice2]
# 4     [mobservice2, mobservice1, logservice1, dbservice2, webservice1]
#
#                                                                                                     root_top5_scores  \
# 0       [0.9509521126747131, 0.03776704519987106, 0.003646757220849395, 0.0021041680593043566, 0.001850126893259585]
# 1        [0.9476569294929504, 0.021491916850209236, 0.00968838669359684, 0.005932621657848358, 0.004757482558488846]
# 2  [0.9996032118797302, 0.0002286632952746004, 5.7833607570501044e-05, 4.961526065017097e-05, 4.040583735331893e-05]
# 3  [0.9988017082214355, 0.0007953429594635963, 0.00012031564983772114, 0.00011408532736822963, 8.94633776624687e-05]
# 4         [0.576850414276123, 0.38371285796165466, 0.006785054691135883, 0.006049088202416897, 0.005666858050972223]
#
#   type_ranked_indices  \
# 0     [2, 3, 1, 0, 4]
# 1     [2, 3, 4, 0, 1]
# 2     [2, 1, 3, 0, 4]
# 3     [2, 1, 3, 0, 4]
# 4     [2, 3, 4, 0, 1]
#
#                                                                                                          type_ranked_names  \
# 0  [[login failure], [memory_anomalies], [file moving program], [access permission denied exception], [normal memory fr...
# 1  [[login failure], [memory_anomalies], [normal memory freed label], [access permission denied exception], [file movin...
# 2  [[login failure], [file moving program], [memory_anomalies], [access permission denied exception], [normal memory fr...
# 3  [[login failure], [file moving program], [memory_anomalies], [access permission denied exception], [normal memory fr...
# 4  [[login failure], [memory_anomalies], [normal memory freed label], [access permission denied exception], [file movin...
#
#                                                                                                    type_ranked_scores
# 0       [0.9826481938362122, 0.005517394747585058, 0.0045023285783827305, 0.004189038649201393, 0.003143054200336337]
# 1       [0.9609946608543396, 0.018749022856354713, 0.011874319054186344, 0.005242393352091312, 0.0031395950354635715]
# 2  [0.9994584918022156, 0.0001925035467138514, 0.00014309071411844343, 0.00013968555140309036, 6.623224908253178e-05]
# 3  [0.998469889163971, 0.0004762022872455418, 0.00046671455493196845, 0.00037421000888571143, 0.00021292442397680134]
# 4       [0.983034610748291, 0.006294824182987213, 0.004315519239753485, 0.0036190422251820564, 0.0027358951047062874]

# %%
focal_025_root_report = classification_report(
    focal_025_df['target_root_name'],
    focal_025_df['pred_root_name'],
    labels=instance_names,
    output_dict=True,
    zero_division=0,
)
focal_025_type_report = classification_report(
    focal_025_df['target_type_name'],
    focal_025_df['pred_type_name'],
    labels=failure_type_names,
    output_dict=True,
    zero_division=0,
)

focal_025_root_report_df = pd.DataFrame(focal_025_root_report).transpose()
focal_025_type_report_df = pd.DataFrame(focal_025_type_report).transpose()

focal_025_root_report_df.to_csv(OUTPUT_DIR / 'focal_025_classification_report_rcl.csv')
focal_025_type_report_df.to_csv(OUTPUT_DIR / 'focal_025_classification_report_fti.csv')

display(focal_025_root_report_df)
display(focal_025_type_report_df)
# Out:
#                precision    recall  f1-score     support
# dbservice1      0.076923  0.028986  0.042105     69.0000
# dbservice2      0.000000  0.000000  0.000000     87.0000
# logservice1     0.000000  0.000000  0.000000     55.0000
# logservice2     0.000000  0.000000  0.000000     51.0000
# mobservice1     0.784827  0.953969  0.861172   6626.0000
# mobservice2     0.955970  0.726232  0.825413   6637.0000
# redisservice1   0.059574  0.297872  0.099291     47.0000
# redisservice2   0.101124  0.187500  0.131387     48.0000
# webservice1     0.083942  0.294872  0.130682     78.0000
# webservice2     0.052632  0.013158  0.021053     76.0000
# accuracy        0.812400  0.812400  0.812400      0.8124
# macro avg       0.211499  0.250259  0.211110  13774.0000
# weighted avg    0.839883  0.812400  0.813857  13774.0000
#                                       precision    recall  f1-score  \
# [access permission denied exception]   0.000000  0.000000  0.000000
# [file moving program]                  0.077399  0.675676  0.138889
# [login failure]                        0.995194  0.976794  0.985908
# [memory_anomalies]                     0.517891  0.487589  0.502283
# [normal memory freed label]            0.000000  0.000000  0.000000
# accuracy                               0.953826  0.953826  0.953826
# macro avg                              0.318097  0.428012  0.325416
# weighted avg                           0.971017  0.953826  0.961682
#
#                                            support
# [access permission denied exception]     15.000000
# [file moving program]                    37.000000
# [login failure]                       13143.000000
# [memory_anomalies]                      564.000000
# [normal memory freed label]              15.000000
# accuracy                                  0.953826
# macro avg                             13774.000000
# weighted avg                          13774.000000

# %%
focal_025_root_cm = confusion_matrix(
    focal_025_df['target_root_name'],
    focal_025_df['pred_root_name'],
    labels=instance_names,
)
focal_025_type_cm = confusion_matrix(
    focal_025_df['target_type_name'],
    focal_025_df['pred_type_name'],
    labels=failure_type_names,
)

pd.DataFrame(focal_025_root_cm, index=instance_names, columns=instance_names).to_csv(OUTPUT_DIR / 'focal_025_confusion_matrix_rcl.csv')
pd.DataFrame(focal_025_type_cm, index=failure_type_names, columns=failure_type_names).to_csv(OUTPUT_DIR / 'focal_025_confusion_matrix_fti.csv')

fig_root = plot_confusion_matrix(focal_025_root_cm, instance_names, 'RCL Confusion Matrix')
fig_type = plot_confusion_matrix(focal_025_type_cm, failure_type_names, 'FTI Confusion Matrix', rotate_x=25)

fig_root.savefig(OUTPUT_DIR / 'focal_025_confusion_matrix_rcl.png', bbox_inches='tight')
fig_type.savefig(OUTPUT_DIR / 'focal_025_confusion_matrix_fti.png', bbox_inches='tight')
plt.show()

# %%
FOCAL_CHECKPOINT_PATH_05 = 'logs/gaia/TransTVDiag-metric-trace-log-root_focal_type_focal-focal_gamma_0.5.pt'
focal_args = Namespace(
    dataset=DATASET,
    labels_file=LABELS_FILE,
    embedding_dim=128,
    graph_hidden=128,
    graph_out=32,
    num_heads=16,
    num_layers=2,
    attn_drop=0.0,
    linear_hidden=[64],
    reconstruct=True,
    aug_percent=0.2,
    N_I = len(instance_names),
    N_T = len(failure_type_names),
    root_loss = 'focal',
    type_loss = 'focal',
    focal_gamma = 0.5
)

focal_05_df = build_predictions_df(
    args=focal_args,
    CHECKPOINT_PATH=FOCAL_CHECKPOINT_PATH_05,
    test_loader=test_loader,
    test_meta=test_meta,
    instance_names=instance_names,
    failure_type_names=failure_type_names,
    instance_id_to_name=instance_id_to_name,
    failure_type_id_to_name=failure_type_id_to_name,
    MainModel=MainModel,
    DEVICE=DEVICE,
)

focal_05_df.head()
# Out:
# From Main Model:  {'metric', 'log', 'trace'}
# Root loss:  focal fault type loss:  focal
# Focal gamma:  0.5
#    sample_position  data_index    datetime     service  \
# 0                0        2431  2021-07-05  mobservice
# 1                1        2432  2021-07-05  mobservice
# 2                2        2433  2021-07-05  mobservice
# 3                3        2434  2021-07-05  mobservice
# 4                4        2435  2021-07-05  mobservice
#
#                                                                                                                    message  \
# 0  2021-07-05 21:42:01,380 | WARNING | 0.0.0.1 | 172.17.0.5 | mobservice1 | 86ec9abb15b5ff80 | wait for 11 seconds for ...
# 1  2021-07-05 21:42:32,616 | WARNING | 0.0.0.4 | 172.17.0.2 | mobservice2 | b13e6cdef1c77e0f | wait for 11 seconds for ...
# 2  2021-07-05 21:45:00,329 | WARNING | 0.0.0.1 | 172.17.0.5 | mobservice1 | 5930623f2070d5ba | wait for 11 seconds for ...
# 3  2021-07-05 21:49:00,904 | WARNING | 0.0.0.1 | 172.17.0.5 | mobservice1 | 2375b8b74da928f8 | wait for 11 seconds for ...
# 4  2021-07-05 21:50:37,731 | WARNING | 0.0.0.4 | 172.17.0.2 | mobservice2 | 286d315a73923371 | wait for 11 seconds for ...
#
#    target_root_idx target_root_name  pred_root_idx pred_root_name  \
# 0                4      mobservice1              4    mobservice1
# 1                5      mobservice2              5    mobservice2
# 2                4      mobservice1              4    mobservice1
# 3                4      mobservice1              4    mobservice1
# 4                5      mobservice2              4    mobservice1
#
#    target_type_idx target_type_name  pred_type_idx   pred_type_name  \
# 0                2  [login failure]              2  [login failure]
# 1                2  [login failure]              2  [login failure]
# 2                2  [login failure]              2  [login failure]
# 3                2  [login failure]              2  [login failure]
# 4                2  [login failure]              2  [login failure]
#
#    root_correct  type_correct  pred_root_confidence  pred_type_confidence  \
# 0          True          True              0.985164              0.999652
# 1          True          True              0.998991              0.999837
# 2          True          True              0.998895              0.999926
# 3          True          True              0.998483              0.999859
# 4         False          True              0.905313              0.999780
#
#   root_top5_indices  \
# 0   [4, 5, 3, 8, 7]
# 1   [5, 4, 9, 0, 3]
# 2   [4, 5, 3, 8, 7]
# 3   [4, 5, 8, 3, 7]
# 4   [4, 5, 3, 8, 0]
#
#                                                        root_top5_names  \
# 0  [mobservice1, mobservice2, logservice2, webservice1, redisservice2]
# 1     [mobservice2, mobservice1, webservice2, dbservice1, logservice2]
# 2  [mobservice1, mobservice2, logservice2, webservice1, redisservice2]
# 3  [mobservice1, mobservice2, webservice1, logservice2, redisservice2]
# 4     [mobservice1, mobservice2, logservice2, webservice1, dbservice1]
#
#                                                                                                       root_top5_scores  \
# 0    [0.9851644039154053, 0.014771392568945885, 1.4674250451207627e-05, 1.4361305147758685e-05, 8.438124496024102e-06]
# 1      [0.9989905953407288, 0.000996638205833733, 6.178474905027542e-06, 4.102259481442161e-06, 6.741718721059442e-07]
# 2  [0.9988954067230225, 0.0010969019494950771, 1.7894446955324383e-06, 1.7419812365915277e-06, 1.5443391703229281e-06]
# 3    [0.9984827637672424, 0.0014987463364377618, 5.769288691226393e-06, 4.510445705818711e-06, 2.6605082439346006e-06]
# 4     [0.9053133130073547, 0.09457267075777054, 2.1748041035607457e-05, 2.061244049400557e-05, 1.7051064787665382e-05]
#
#   type_ranked_indices  \
# 0     [2, 3, 0, 1, 4]
# 1     [2, 3, 4, 0, 1]
# 2     [2, 3, 0, 1, 4]
# 3     [2, 3, 0, 1, 4]
# 4     [2, 3, 0, 4, 1]
#
#                                                                                                          type_ranked_names  \
# 0  [[login failure], [memory_anomalies], [access permission denied exception], [file moving program], [normal memory fr...
# 1  [[login failure], [memory_anomalies], [normal memory freed label], [access permission denied exception], [file movin...
# 2  [[login failure], [memory_anomalies], [access permission denied exception], [file moving program], [normal memory fr...
# 3  [[login failure], [memory_anomalies], [access permission denied exception], [file moving program], [normal memory fr...
# 4  [[login failure], [memory_anomalies], [access permission denied exception], [normal memory freed label], [file movin...
#
#                                                                                                    type_ranked_scores
# 0     [0.9996522665023804, 0.00013760682486463338, 8.956492820288986e-05, 6.54992982163094e-05, 5.51262783119455e-05]
# 1    [0.9998373985290527, 8.569149213144556e-05, 4.35457332059741e-05, 2.078686338791158e-05, 1.2515934940893203e-05]
# 2  [0.9999264478683472, 2.8061082048225217e-05, 2.1639138140017167e-05, 1.5873558368184604e-05, 7.92257378634531e-06]
# 3     [0.9998594522476196, 5.131807483849116e-05, 4.16015500377398e-05, 3.102664413745515e-05, 1.655794767430052e-05]
# 4     [0.999779999256134, 8.763703954173252e-05, 5.341075666365214e-05, 3.996688610641286e-05, 3.902549360645935e-05]

# %%
focal_05_root_report = classification_report(
    focal_05_df['target_root_name'],
    focal_05_df['pred_root_name'],
    labels=instance_names,
    output_dict=True,
    zero_division=0,
)
focal_05_type_report = classification_report(
    focal_05_df['target_type_name'],
    focal_05_df['pred_type_name'],
    labels=failure_type_names,
    output_dict=True,
    zero_division=0,
)

focal_05_root_report_df = pd.DataFrame(focal_05_root_report).transpose()
focal_05_type_report_df = pd.DataFrame(focal_05_type_report).transpose()

focal_05_root_report_df.to_csv(OUTPUT_DIR / 'focal_05_classification_report_rcl.csv')
focal_05_type_report_df.to_csv(OUTPUT_DIR / 'focal_05_classification_report_fti.csv')

display(focal_05_root_report_df)
display(focal_05_type_report_df)
# Out:
#                precision    recall  f1-score       support
# dbservice1      0.090909  0.028986  0.043956     69.000000
# dbservice2      0.000000  0.000000  0.000000     87.000000
# logservice1     0.061538  0.290909  0.101587     55.000000
# logservice2     0.000000  0.000000  0.000000     51.000000
# mobservice1     0.861005  0.922729  0.890799   6626.000000
# mobservice2     0.908546  0.845713  0.876005   6637.000000
# redisservice1   0.029412  0.042553  0.034783     47.000000
# redisservice2   0.063492  0.083333  0.072072     48.000000
# webservice1     0.055556  0.012821  0.020833     78.000000
# webservice2     0.259259  0.184211  0.215385     76.000000
# accuracy        0.854218  0.854218  0.854218      0.854218
# macro avg       0.232972  0.241125  0.225542  13774.000000
# weighted avg    0.854739  0.854218  0.852925  13774.000000
#                                       precision    recall  f1-score  \
# [access permission denied exception]   0.000000  0.000000  0.000000
# [file moving program]                  0.352941  0.324324  0.338028
# [login failure]                        0.999315  0.999467  0.999391
# [memory_anomalies]                     0.925676  0.971631  0.948097
# [normal memory freed label]            0.333333  0.066667  0.111111
# accuracy                               0.994410  0.994410  0.994410
# macro avg                              0.522253  0.472418  0.479326
# weighted avg                           0.992750  0.994410  0.993459
#
#                                           support
# [access permission denied exception]     15.00000
# [file moving program]                    37.00000
# [login failure]                       13143.00000
# [memory_anomalies]                      564.00000
# [normal memory freed label]              15.00000
# accuracy                                  0.99441
# macro avg                             13774.00000
# weighted avg                          13774.00000

# %%
focal_05_root_cm = confusion_matrix(
    focal_05_df['target_root_name'],
    focal_05_df['pred_root_name'],
    labels=instance_names,
)
focal_05_type_cm = confusion_matrix(
    focal_05_df['target_type_name'],
    focal_05_df['pred_type_name'],
    labels=failure_type_names,
)

pd.DataFrame(focal_05_root_cm, index=instance_names, columns=instance_names).to_csv(OUTPUT_DIR / 'focal_05_confusion_matrix_rcl.csv')
pd.DataFrame(focal_05_type_cm, index=failure_type_names, columns=failure_type_names).to_csv(OUTPUT_DIR / 'focal_05_confusion_matrix_fti.csv')

fig_root = plot_confusion_matrix(focal_05_root_cm, instance_names, 'RCL Confusion Matrix')
fig_type = plot_confusion_matrix(focal_05_type_cm, failure_type_names, 'FTI Confusion Matrix', rotate_x=25)

fig_root.savefig(OUTPUT_DIR / 'focal_05_confusion_matrix_rcl.png', bbox_inches='tight')
fig_type.savefig(OUTPUT_DIR / 'focal_05_confusion_matrix_fti.png', bbox_inches='tight')
plt.show()

# %%
FOCAL_CHECKPOINT_PATH_075 = 'logs/gaia/TransTVDiag-metric-trace-log-root_focal_type_focal-focal_gamma_0.75.pt'
focal_args = Namespace(
    dataset=DATASET,
    labels_file=LABELS_FILE,
    embedding_dim=128,
    graph_hidden=128,
    graph_out=32,
    num_heads=16,
    num_layers=2,
    attn_drop=0.0,
    linear_hidden=[64],
    reconstruct=True,
    aug_percent=0.2,
    N_I = len(instance_names),
    N_T = len(failure_type_names),
    root_loss = 'focal',
    type_loss = 'focal',
    focal_gamma = 0.75
)

focal_075_df = build_predictions_df(
    args=focal_args,
    CHECKPOINT_PATH=FOCAL_CHECKPOINT_PATH_075,
    test_loader=test_loader,
    test_meta=test_meta,
    instance_names=instance_names,
    failure_type_names=failure_type_names,
    instance_id_to_name=instance_id_to_name,
    failure_type_id_to_name=failure_type_id_to_name,
    MainModel=MainModel,
    DEVICE=DEVICE,
)

focal_075_df.head()
# Out:
# From Main Model:  {'metric', 'log', 'trace'}
# Root loss:  focal fault type loss:  focal
# Focal gamma:  0.75
#    sample_position  data_index    datetime     service  \
# 0                0        2431  2021-07-05  mobservice
# 1                1        2432  2021-07-05  mobservice
# 2                2        2433  2021-07-05  mobservice
# 3                3        2434  2021-07-05  mobservice
# 4                4        2435  2021-07-05  mobservice
#
#                                                                                                                    message  \
# 0  2021-07-05 21:42:01,380 | WARNING | 0.0.0.1 | 172.17.0.5 | mobservice1 | 86ec9abb15b5ff80 | wait for 11 seconds for ...
# 1  2021-07-05 21:42:32,616 | WARNING | 0.0.0.4 | 172.17.0.2 | mobservice2 | b13e6cdef1c77e0f | wait for 11 seconds for ...
# 2  2021-07-05 21:45:00,329 | WARNING | 0.0.0.1 | 172.17.0.5 | mobservice1 | 5930623f2070d5ba | wait for 11 seconds for ...
# 3  2021-07-05 21:49:00,904 | WARNING | 0.0.0.1 | 172.17.0.5 | mobservice1 | 2375b8b74da928f8 | wait for 11 seconds for ...
# 4  2021-07-05 21:50:37,731 | WARNING | 0.0.0.4 | 172.17.0.2 | mobservice2 | 286d315a73923371 | wait for 11 seconds for ...
#
#    target_root_idx target_root_name  pred_root_idx pred_root_name  \
# 0                4      mobservice1              4    mobservice1
# 1                5      mobservice2              4    mobservice1
# 2                4      mobservice1              4    mobservice1
# 3                4      mobservice1              4    mobservice1
# 4                5      mobservice2              4    mobservice1
#
#    target_type_idx target_type_name  pred_type_idx   pred_type_name  \
# 0                2  [login failure]              2  [login failure]
# 1                2  [login failure]              2  [login failure]
# 2                2  [login failure]              2  [login failure]
# 3                2  [login failure]              2  [login failure]
# 4                2  [login failure]              2  [login failure]
#
#    root_correct  type_correct  pred_root_confidence  pred_type_confidence  \
# 0          True          True              0.997063              0.998541
# 1         False          True              0.999449              0.999053
# 2          True          True              0.999240              0.998643
# 3          True          True              0.999367              0.998397
# 4         False          True              0.998368              0.998745
#
#   root_top5_indices  \
# 0   [4, 5, 8, 9, 7]
# 1   [4, 5, 7, 8, 9]
# 2   [4, 5, 7, 8, 9]
# 3   [4, 5, 8, 7, 9]
# 4   [4, 5, 8, 9, 7]
#
#                                                        root_top5_names  \
# 0  [mobservice1, mobservice2, webservice1, webservice2, redisservice2]
# 1  [mobservice1, mobservice2, redisservice2, webservice1, webservice2]
# 2  [mobservice1, mobservice2, redisservice2, webservice1, webservice2]
# 3  [mobservice1, mobservice2, webservice1, redisservice2, webservice2]
# 4  [mobservice1, mobservice2, webservice1, webservice2, redisservice2]
#
#                                                                                                       root_top5_scores  \
# 0     [0.9970629811286926, 0.0027531429659575224, 4.862874993705191e-05, 3.845515675493516e-05, 3.392872531549074e-05]
# 1  [0.9994489550590515, 0.0004978020442649722, 1.5102319594006985e-05, 1.2158084246038925e-05, 1.0728141205618158e-05]
# 2    [0.9992402791976929, 0.0006739383679814637, 2.336404395464342e-05, 1.8109343727701344e-05, 1.720546424621716e-05]
# 3   [0.9993672966957092, 0.0005304828519001603, 2.5863422706606798e-05, 2.5861991161946207e-05, 2.066228262265213e-05]
# 4  [0.9983682036399841, 0.0015279088402166963, 2.9601114874822088e-05, 2.2288120817393064e-05, 2.1025251044193283e-05]
#
#   type_ranked_indices  \
# 0     [2, 0, 1, 3, 4]
# 1     [2, 0, 3, 1, 4]
# 2     [2, 0, 3, 1, 4]
# 3     [2, 0, 1, 3, 4]
# 4     [2, 0, 1, 3, 4]
#
#                                                                                                          type_ranked_names  \
# 0  [[login failure], [access permission denied exception], [file moving program], [memory_anomalies], [normal memory fr...
# 1  [[login failure], [access permission denied exception], [memory_anomalies], [file moving program], [normal memory fr...
# 2  [[login failure], [access permission denied exception], [memory_anomalies], [file moving program], [normal memory fr...
# 3  [[login failure], [access permission denied exception], [file moving program], [memory_anomalies], [normal memory fr...
# 4  [[login failure], [access permission denied exception], [file moving program], [memory_anomalies], [normal memory fr...
#
#                                                                                                     type_ranked_scores
# 0  [0.9985414743423462, 0.00041350870742462575, 0.0003845666942652315, 0.00036822794936597347, 0.00029221686418168247]
# 1   [0.9990529417991638, 0.0002666011278051883, 0.00025296956300735474, 0.0002454384812153876, 0.00018205550441052765]
# 2    [0.9986431002616882, 0.0003783332067541778, 0.00036010699113830924, 0.0003346539451740682, 0.0002838213404174894]
# 3     [0.998397171497345, 0.000445749843493104, 0.0004111310699954629, 0.00041026039980351925, 0.00033578157308511436]
# 4   [0.9987450838088989, 0.0003385890740901232, 0.00033294770400971174, 0.0003077516157645732, 0.00027560090529732406]

# %%
focal_075_root_report = classification_report(
    focal_075_df['target_root_name'],
    focal_075_df['pred_root_name'],
    labels=instance_names,
    output_dict=True,
    zero_division=0,
)
focal_075_type_report = classification_report(
    focal_075_df['target_type_name'],
    focal_075_df['pred_type_name'],
    labels=failure_type_names,
    output_dict=True,
    zero_division=0,
)

focal_075_root_report_df = pd.DataFrame(focal_075_root_report).transpose()
focal_075_type_report_df = pd.DataFrame(focal_075_type_report).transpose()

focal_075_root_report_df.to_csv(OUTPUT_DIR / 'focal_075_classification_report_rcl.csv')
focal_075_type_report_df.to_csv(OUTPUT_DIR / 'focal_075_classification_report_fti.csv')

display(focal_075_root_report_df)
display(focal_075_type_report_df)
# Out:
#                precision    recall  f1-score      support
# dbservice1      0.071429  0.028986  0.041237     69.00000
# dbservice2      0.000000  0.000000  0.000000     87.00000
# logservice1     0.000000  0.000000  0.000000     55.00000
# logservice2     0.000000  0.000000  0.000000     51.00000
# mobservice1     0.546259  0.987323  0.703365   6626.00000
# mobservice2     0.952438  0.241374  0.385142   6637.00000
# redisservice1   0.044444  0.042553  0.043478     47.00000
# redisservice2   0.000000  0.000000  0.000000     48.00000
# webservice1     0.000000  0.000000  0.000000     78.00000
# webservice2     0.114286  0.052632  0.072072     76.00000
# accuracy        0.591840  0.591840  0.591840      0.59184
# macro avg       0.172886  0.135287  0.124530  13774.00000
# weighted avg    0.722851  0.591840  0.524688  13774.00000
#                                       precision    recall  f1-score  \
# [access permission denied exception]   0.000000  0.000000  0.000000
# [file moving program]                  0.076923  0.135135  0.098039
# [login failure]                        0.979718  0.955566  0.967491
# [memory_anomalies]                     0.328090  0.517730  0.401651
# [normal memory freed label]            0.000000  0.000000  0.000000
# accuracy                               0.933353  0.933353  0.933353
# macro avg                              0.276946  0.321686  0.293436
# weighted avg                           0.948477  0.933353  0.939879
#
#                                            support
# [access permission denied exception]     15.000000
# [file moving program]                    37.000000
# [login failure]                       13143.000000
# [memory_anomalies]                      564.000000
# [normal memory freed label]              15.000000
# accuracy                                  0.933353
# macro avg                             13774.000000
# weighted avg                          13774.000000

# %%
focal_075_root_cm = confusion_matrix(
    focal_075_df['target_root_name'],
    focal_075_df['pred_root_name'],
    labels=instance_names,
)
focal_075_type_cm = confusion_matrix(
    focal_075_df['target_type_name'],
    focal_075_df['pred_type_name'],
    labels=failure_type_names,
)

pd.DataFrame(focal_075_root_cm, index=instance_names, columns=instance_names).to_csv(OUTPUT_DIR / 'focal_075_confusion_matrix_rcl.csv')
pd.DataFrame(focal_075_type_cm, index=failure_type_names, columns=failure_type_names).to_csv(OUTPUT_DIR / 'focal_075_confusion_matrix_fti.csv')

fig_root = plot_confusion_matrix(focal_075_root_cm, instance_names, 'RCL Confusion Matrix')
fig_type = plot_confusion_matrix(focal_075_type_cm, failure_type_names, 'FTI Confusion Matrix', rotate_x=25)

fig_root.savefig(OUTPUT_DIR / 'focal_075_confusion_matrix_rcl.png', bbox_inches='tight')
fig_type.savefig(OUTPUT_DIR / 'focal_075_confusion_matrix_fti.png', bbox_inches='tight')
plt.show()

# %%
WEIGHTED_FOCAL_CHECKPOINT_PATH = 'logs/gaia/TransTVDiag-metric-trace-log-root_weighted_focal_type_weighted_focal.pt'
weighted_focal_args = Namespace(
    dataset=DATASET,
    labels_file=LABELS_FILE,
    embedding_dim=128,
    graph_hidden=128,
    graph_out=32,
    num_heads=16,
    num_layers=2,
    attn_drop=0.0,
    linear_hidden=[64],
    reconstruct=True,
    aug_percent=0.2,
    N_I = len(instance_names),
    N_T = len(failure_type_names),
    root_loss = 'weighted_focal',
    type_loss = 'weighted_focal'
)

weighted_focal_df = build_predictions_df(
    args=weighted_focal_args,
    CHECKPOINT_PATH=WEIGHTED_FOCAL_CHECKPOINT_PATH,
    test_loader=test_loader,
    test_meta=test_meta,
    instance_names=instance_names,
    failure_type_names=failure_type_names,
    instance_id_to_name=instance_id_to_name,
    failure_type_id_to_name=failure_type_id_to_name,
    MainModel=MainModel,
    DEVICE=DEVICE,
)

weighted_focal_df.head()
# Out:
# From Main Model:  {'trace', 'log', 'metric'}
#    sample_position  data_index    datetime     service  \
# 0                0        2431  2021-07-05  mobservice
# 1                1        2432  2021-07-05  mobservice
# 2                2        2433  2021-07-05  mobservice
# 3                3        2434  2021-07-05  mobservice
# 4                4        2435  2021-07-05  mobservice
#
#                                                                                                                    message  \
# 0  2021-07-05 21:42:01,380 | WARNING | 0.0.0.1 | 172.17.0.5 | mobservice1 | 86ec9abb15b5ff80 | wait for 11 seconds for ...
# 1  2021-07-05 21:42:32,616 | WARNING | 0.0.0.4 | 172.17.0.2 | mobservice2 | b13e6cdef1c77e0f | wait for 11 seconds for ...
# 2  2021-07-05 21:45:00,329 | WARNING | 0.0.0.1 | 172.17.0.5 | mobservice1 | 5930623f2070d5ba | wait for 11 seconds for ...
# 3  2021-07-05 21:49:00,904 | WARNING | 0.0.0.1 | 172.17.0.5 | mobservice1 | 2375b8b74da928f8 | wait for 11 seconds for ...
# 4  2021-07-05 21:50:37,731 | WARNING | 0.0.0.4 | 172.17.0.2 | mobservice2 | 286d315a73923371 | wait for 11 seconds for ...
#
#    target_root_idx target_root_name  pred_root_idx pred_root_name  \
# 0                4      mobservice1              5    mobservice2
# 1                5      mobservice2              5    mobservice2
# 2                4      mobservice1              4    mobservice1
# 3                4      mobservice1              4    mobservice1
# 4                5      mobservice2              5    mobservice2
#
#    target_type_idx target_type_name  pred_type_idx   pred_type_name  \
# 0                2  [login failure]              2  [login failure]
# 1                2  [login failure]              2  [login failure]
# 2                2  [login failure]              2  [login failure]
# 3                2  [login failure]              2  [login failure]
# 4                2  [login failure]              2  [login failure]
#
#    root_correct  type_correct  pred_root_confidence  pred_type_confidence  \
# 0         False          True              0.668561              0.968228
# 1          True          True              0.929000              0.944099
# 2          True          True              0.635161              0.997156
# 3          True          True              0.582305              0.997979
# 4          True          True              0.708856              0.994721
#
#   root_top5_indices  \
# 0   [5, 4, 9, 0, 6]
# 1   [5, 0, 4, 1, 9]
# 2   [4, 5, 7, 3, 9]
# 3   [4, 5, 7, 6, 3]
# 4   [5, 4, 1, 9, 0]
#
#                                                          root_top5_names  \
# 0     [mobservice2, mobservice1, webservice2, dbservice1, redisservice1]
# 1        [mobservice2, dbservice1, mobservice1, dbservice2, webservice2]
# 2    [mobservice1, mobservice2, redisservice2, logservice2, webservice2]
# 3  [mobservice1, mobservice2, redisservice2, redisservice1, logservice2]
# 4        [mobservice2, mobservice1, dbservice2, webservice2, dbservice1]
#
#                                                                                                   root_top5_scores  \
# 0  [0.6685613989830017, 0.33115872740745544, 0.00012788227468263358, 5.988128395983949e-05, 4.529470606939867e-05]
# 1   [0.9290000200271606, 0.03814665600657463, 0.025864094495773315, 0.0067609199322760105, 0.00017694960115477443]
# 2    [0.6351605653762817, 0.364540159702301, 0.00022011161490809172, 4.66786659671925e-05, 1.5547742805210873e-05]
# 3  [0.5823052525520325, 0.4175705015659332, 8.510438055964187e-05, 1.6983582099783234e-05, 1.0730776011769194e-05]
# 4     [0.708856463432312, 0.28682827949523926, 0.003190056188032031, 0.0006597851170226932, 0.0003437254636082798]
#
#   type_ranked_indices  \
# 0     [2, 4, 3, 1, 0]
# 1     [2, 4, 3, 0, 1]
# 2     [2, 4, 3, 1, 0]
# 3     [2, 4, 3, 1, 0]
# 4     [2, 4, 3, 1, 0]
#
#                                                                                                          type_ranked_names  \
# 0  [[login failure], [normal memory freed label], [memory_anomalies], [file moving program], [access permission denied ...
# 1  [[login failure], [normal memory freed label], [memory_anomalies], [access permission denied exception], [file movin...
# 2  [[login failure], [normal memory freed label], [memory_anomalies], [file moving program], [access permission denied ...
# 3  [[login failure], [normal memory freed label], [memory_anomalies], [file moving program], [access permission denied ...
# 4  [[login failure], [normal memory freed label], [memory_anomalies], [file moving program], [access permission denied ...
#
#                                                                                                    type_ranked_scores
# 0    [0.9682281017303467, 0.03128427267074585, 0.00042217946611344814, 4.315309342928231e-05, 2.2296848328551278e-05]
# 1      [0.9440991282463074, 0.03704666346311569, 0.018815631046891212, 3.4433091059327126e-05, 4.136723873671144e-06]
# 2    [0.9971561431884766, 0.0021664367523044348, 0.0005635659326799214, 9.364877041662112e-05, 2.016285179706756e-05]
# 3   [0.9979791045188904, 0.0016305851750075817, 0.00032599776750430465, 5.12839833390899e-05, 1.3109749488648959e-05]
# 4  [0.9947210550308228, 0.0044169132597744465, 0.0008220833842642605, 2.5956569515983574e-05, 1.3987716556584928e-05]

# %%
weighted_focal_root_cm = confusion_matrix(
    weighted_focal_df['target_root_name'],
    weighted_focal_df['pred_root_name'],
    labels=instance_names,
)
weighted_focal_type_cm = confusion_matrix(
    weighted_focal_df['target_type_name'],
    weighted_focal_df['pred_type_name'],
    labels=failure_type_names,
)

pd.DataFrame(weighted_focal_root_cm, index=instance_names, columns=instance_names).to_csv(OUTPUT_DIR / 'weighted_focal_confusion_matrix_rcl.csv')
pd.DataFrame(weighted_focal_type_cm, index=failure_type_names, columns=failure_type_names).to_csv(OUTPUT_DIR / 'weighted_focal_confusion_matrix_fti.csv')

fig_root = plot_confusion_matrix(weighted_focal_root_cm, instance_names, 'RCL Confusion Matrix')
fig_type = plot_confusion_matrix(weighted_focal_type_cm, failure_type_names, 'FTI Confusion Matrix', rotate_x=25)

fig_root.savefig(OUTPUT_DIR / 'weighted_focal_confusion_matrix_rcl.png', bbox_inches='tight')
fig_type.savefig(OUTPUT_DIR / 'weighted_focal_confusion_matrix_fti.png', bbox_inches='tight')
plt.show()

# %%
weighted_focal_root_report = classification_report(
    weighted_focal_df['target_root_name'],
    weighted_focal_df['pred_root_name'],
    labels=instance_names,
    output_dict=True,
    zero_division=0,
)
weighted_focal_type_report = classification_report(
    weighted_focal_df['target_type_name'],
    weighted_focal_df['pred_type_name'],
    labels=failure_type_names,
    output_dict=True,
    zero_division=0,
)

weighted_focal_root_report_df = pd.DataFrame(weighted_focal_root_report).transpose()
weighted_focal_type_report_df = pd.DataFrame(weighted_focal_type_report).transpose()

weighted_focal_root_report_df.to_csv(OUTPUT_DIR / 'weighted_focal_classification_report_rcl.csv')
weighted_focal_type_report_df.to_csv(OUTPUT_DIR / 'weighted_focal_classification_report_fti.csv')

display(weighted_focal_root_report_df)
display(weighted_focal_type_report_df)
# Out:
#                precision    recall  f1-score       support
# dbservice1      0.032258  0.028986  0.030534     69.000000
# dbservice2      0.132530  0.252874  0.173913     87.000000
# logservice1     0.076923  0.018182  0.029412     55.000000
# logservice2     0.115942  0.156863  0.133333     51.000000
# mobservice1     0.976859  0.777241  0.865692   6626.000000
# mobservice2     0.820434  0.963086  0.886055   6637.000000
# redisservice1   0.076271  0.382979  0.127208     47.000000
# redisservice2   0.112150  0.250000  0.154839     48.000000
# webservice1     0.074074  0.025641  0.038095     78.000000
# webservice2     0.096774  0.039474  0.056075     76.000000
# accuracy        0.842892  0.842892  0.842892      0.842892
# macro avg       0.251421  0.289532  0.249516  13774.000000
# weighted avg    0.868585  0.842892  0.846749  13774.000000
#                                       precision    recall  f1-score  \
# [access permission denied exception]   0.000000  0.000000  0.000000
# [file moving program]                  0.500000  0.108108  0.177778
# [login failure]                        0.999309  0.990261  0.994764
# [memory_anomalies]                     0.882353  0.904255  0.893170
# [normal memory freed label]            0.006098  0.066667  0.011173
# accuracy                               0.982285  0.982285  0.982285
# macro avg                              0.477552  0.413858  0.415377
# weighted avg                           0.991009  0.982285  0.986255
#
#                                            support
# [access permission denied exception]     15.000000
# [file moving program]                    37.000000
# [login failure]                       13143.000000
# [memory_anomalies]                      564.000000
# [normal memory freed label]              15.000000
# accuracy                                  0.982285
# macro avg                             13774.000000
# weighted avg                          13774.000000
