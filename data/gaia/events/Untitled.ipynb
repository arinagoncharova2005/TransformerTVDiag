# %%
pos = 2293760
path = "log.json"
print(len(data))

with open(path, "r", encoding="utf-8") as f:
    data = f.read()

start = max(0, pos)
end = min(len(data), pos + 10)

print(data[start:end])
print("\n" + " " * (pos - start) + "^ HERE")
# Out:
# 13697024
#       ],
#
#
# ^ HERE
